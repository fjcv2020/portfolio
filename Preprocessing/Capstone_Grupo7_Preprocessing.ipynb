# %% [markdown]
# **CAPSTONE EASY MONEY // 02SDCESP0223 - GRUPO 7**

# %% [markdown]
# ## Introducción al Capstone Fintech -Easy Money
#
# Este proyecto tiene como objetivo realizar un caso semejante a la vida real, en el que realizaremos las tareas solicitadas a Bob, un nuevo trabajador de una compañía comercializadora de productos financieros llamada Easy Money.
#
# A Bob se le ha contratado debido a sus conocimientos en Data Science, debido a que la empresa requiere incorporar la analítica en todos los procesos core. La empresa cuenta con un autoservicio de BI con ReportServer por lo que podemos considerar que se encuentra en la fase 4. Reporting Avanzado / estratégico del Módelo de Madurez de Analytics, por lo que quedaría pendiente trabajar en la modelización predictiva de los productos a vender y la analítica prescriptiva de la empresa.
#
# Es por ello, que empezamos conociendo este Notebook, la información de la empresa proporcionada por el área de IT, la cual consta de 5 archivos .CSV que resumiremos a continuación y en el que pueden conocer más en el archivo adjunto Tablas - Descripción.xlsx.
#
# Se nos han entregado 5 archivos:
# 1. **customer_commercial_Activity**: con 5.962.924 records (filas), donde se otorga una primera vista a la base de clientes de Easy Money, la cual puede entenderse como la base de información de cada cliente durante los meses analizados (pk_partition)
#
# 2. **customer_products**: con 5.962.924 records (filas), donde se observa los productos activos de cada cliente durante los meses analizados (pk_partition). En su mayoría son columnas booleanas (para los productos) y permite observar la evolución (altas y bajas) de los productos que cada cliente mantiene con Easy Money.
#
# 3. **customer_sociodemographic**: con 5.962.924 records (filas), se observa la información personal de cada cliente durante los meses analizados (pk_partition). Esta información nos permite conocer más a los clientes y segmentar de la mejor manera.
#
# 4. **sales**: con 240.772 records (filas), se observar las ventas realizadas durante 16 meses (month_Sale). Además, el producto y el margen neto cada venta.
#
# 5. **product_description**: con 13 records (filas), se hace referencia a los productos y familia de productos de Easy money.
#
# Para el correcto preprocesamiento de las tablas, hemos realizado una primera vista buscando duplicados y nulos. Posteriormente, se ha trabajado cada columna para homogenizar las variables, trabajar los nulos y cambiar el tipo de variable.
#
# Posteriormente, hemos creado el modelo relacional de los datos. Donde en una primera instancia se ha realizado join de las tablas customer_commercial_Activity, customer_products y customer_sociodemographic, para trabajar la información de cada cliente en una misma tabla. Por otro lado, se ha realizado un join para las tablas de sales y product_description. De esta manera, conoceremos el productos y su familia para cada venta realizada.
#
# Realizado este procesamiento y teniendo una mejor visión de la información, hemos creado nuevas variables y nuevas tablas que nos ayudarán a profundizar en el entendimeinto del negocio.
#
# Al final del proyecto, tendremos un entendimiento más profundo de la información de los clientes y las ventas realizadas.
#
# Trabajo realizado por:
# * **Francisco Camacho**
# * **Mariela Drago**

# %% [markdown]
# ### Montamos drive e importamos las librerías necesarias

# %%
# Montamos Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importamos las librerías necesarias
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

plt.style.use("ggplot")

from google.colab import files

from sklearn import model_selection
import xgboost as xgb

from scipy import stats
from datetime import datetime
import random

#import xgboost as xgb
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
#from sklearn.ensemble import GradientBoostingClassifier
#from sklearn.svm import SVC
#from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Cargamos los datos facilitados

# %%
# Cargar los datos

DATA_PATH = "/content/drive/MyDrive/MDS - Grupo 7/Capstone/datasets_TFM + diccionario"
customer_commercial_activity = pd.read_csv(DATA_PATH+ "/customer_commercial_activity.csv")
customer_products = pd.read_csv(DATA_PATH + "/customer_products.csv")
customer_sociodemographics = pd.read_csv(DATA_PATH + "/customer_sociodemographics.csv")
sales = pd.read_csv(DATA_PATH + "/sales.csv")
product_description = pd.read_csv(DATA_PATH + "/product_description.csv")

# %%
customer_commercial_activity.name = 'customer_commercial_activity'
customer_products.name = 'customer_products'
customer_sociodemographics.name = 'customer_sociodemographics'
sales.name = 'sales'
product_description.name = 'product_description'

# %%
df_juntos = {'customer_commercial_activity': customer_commercial_activity, 'customer_products': customer_products, 'customer_sociodemographics': customer_sociodemographics, 'sales': sales, 'product_description':product_description}

# %% [markdown]
# # **1. Data Understanding y Data cleaning**

# %%
#Descargamos el info y describe de cada tabla para conocer a detalle cada variable

# %%
def download_csv(df):
  download1 = df.describe(include = 'all').T
  download1.to_csv(f'{df.name}_describe.csv')
  return files.download (f'{df.name}_describe.csv')

# %%
#download_csv(customer_commercial_activity)
#download_csv(customer_products)
#download_csv(customer_sociodemographics)
#download_csv(sales)
#download_csv(product_description)

# %%
def info_data (*dataframes):
  for df in dataframes:
    print(f"Información del dataframe {df.name}:")
    df.info()
    print("\n")

# %%
info_data (customer_commercial_activity, customer_products, customer_sociodemographics, sales, product_description)
# Out:
# Información del dataframe customer_commercial_activity:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 7 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0       int64
#  1   pk_cid           int64
#  2   pk_partition     object
#  3   entry_date       object
#  4   entry_channel    object
#  5   active_customer  float64
#  6   segment          object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 318.5+ MB
#
#
# Información del dataframe customer_products:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 18 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   pk_cid              int64
#  2   pk_partition        object
#  3   short_term_deposit  int64
#  4   loans               int64
#  5   mortgage            int64
#  6   funds               int64
#  7   securities          int64
#  8   long_term_deposit   int64
#  9   em_account_pp       int64
#  10  credit_card         int64
#  11  payroll             float64
#  12  pension_plan        float64
#  13  payroll_account     int64
#  14  emc_account         int64
#  15  debit_card          int64
#  16  em_account_p        int64
#  17  em_acount           int64
# dtypes: float64(2), int64(15), object(1)
# memory usage: 818.9+ MB
#
#
# Información del dataframe customer_sociodemographics:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    int64
#  1   pk_cid        int64
#  2   pk_partition  object
#  3   country_id    object
#  4   region_code   float64
#  5   gender        object
#  6   age           int64
#  7   deceased      object
#  8   salary        float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 409.4+ MB
#
#
# Información del dataframe sales:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240773 entries, 0 to 240772
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  240773 non-null  int64
#  1   pk_sale     240773 non-null  int64
#  2   cid         240773 non-null  int64
#  3   month_sale  240773 non-null  object
#  4   product_ID  240773 non-null  int64
#  5   net_margin  240773 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 11.0+ MB
#
#
# Información del dataframe product_description:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      13 non-null     int64
#  1   pk_product_ID   13 non-null     int64
#  2   product_desc    13 non-null     object
#  3   family_product  13 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 544.0+ bytes

# %%
customer_commercial_activity[(customer_commercial_activity["pk_cid"]==1387215)]
# Out:
#          Unnamed: 0   pk_cid pk_partition entry_date entry_channel  \
# 584084      1667901  1387215      2018-03    2018-03           KHK
# 836838      2305122  1387215      2018-04    2018-03           KHK
# 1121946     2727756  1387215      2018-05    2018-03           KHK
# 1371157     3357237  1387215      2018-06    2018-03           KHK
# 1771509     4561710  1387215      2018-07    2018-03           KHK
# 1990769     5077214  1387215      2018-08    2018-03           KHK
# 2453837     6224434  1387215      2018-09    2018-03           KHK
# 2772483     6590990  1387215      2018-10    2018-03           KHK
# 3190683     7820090  1387215      2018-11    2018-03           KHK
# 3773815     9013628  1387215      2018-12    2018-03           KHK
# 3943637     9313045  1387215      2019-01    2018-03           KHK
# 4445133    10174361  1387215      2019-02    2018-03           KHK
# 4837960    11056365  1387215      2019-03    2018-03           KHK
# 5300716    12496625  1387215      2019-04    2018-03           KHK
# 5577019    13233913  1387215      2019-05    2018-03           KHK
#
#          active_customer            segment
# 584084               1.0           01 - TOP
# 836838               1.0           01 - TOP
# 1121946              1.0           01 - TOP
# 1371157              1.0           01 - TOP
# 1771509              1.0           01 - TOP
# 1990769              1.0           01 - TOP
# 2453837              1.0           01 - TOP
# 2772483              1.0           01 - TOP
# 3190683              1.0           01 - TOP
# 3773815              1.0           01 - TOP
# 3943637              1.0  02 - PARTICULARES
# 4445133              1.0  02 - PARTICULARES
# 4837960              1.0  02 - PARTICULARES
# 5300716              1.0           01 - TOP
# 5577019              1.0           01 - TOP

# %%
def describe_num(dataframes):
    df_descriptions = pd.DataFrame()

    for name, df in dataframes.items():
        description = df.describe(include = np.number).T
        description['DataFrame'] = name
        df_descriptions = pd.concat([df_descriptions, description])

    return df_descriptions

# %%
describe_num(df_juntos)
# Out:
#                         count          mean           std       min  \
# Unnamed: 0          5962924.0  7.155425e+06  3.920784e+06      0.00
# pk_cid              5962924.0  1.234930e+06  1.623020e+05  15891.00
# active_customer     5962924.0  4.033845e-01  4.905767e-01      0.00
# Unnamed: 0          5962924.0  7.155425e+06  3.920784e+06      0.00
# pk_cid              5962924.0  1.234930e+06  1.623020e+05  15891.00
# short_term_deposit  5962924.0  2.581619e-03  5.074401e-02      0.00
# loans               5962924.0  7.848498e-05  8.858828e-03      0.00
# mortgage            5962924.0  5.433576e-05  7.371080e-03      0.00
# funds               5962924.0  3.370662e-03  5.795948e-02      0.00
# securities          5962924.0  3.711770e-03  6.081113e-02      0.00
# long_term_deposit   5962924.0  1.688098e-02  1.288255e-01      0.00
# em_account_pp       5962924.0  0.000000e+00  0.000000e+00      0.00
# credit_card         5962924.0  1.188444e-02  1.083660e-01      0.00
# payroll             5962863.0  3.451144e-02  1.825388e-01      0.00
# pension_plan        5962863.0  3.652641e-02  1.875960e-01      0.00
# payroll_account     5962924.0  5.524471e-02  2.284573e-01      0.00
# emc_account         5962924.0  5.483233e-02  2.276527e-01      0.00
# debit_card          5962924.0  9.441140e-02  2.924002e-01      0.00
# em_account_p        5962924.0  5.701901e-06  2.387859e-03      0.00
# em_acount           5962924.0  7.348076e-01  4.414356e-01      0.00
# Unnamed: 0          5962924.0  7.155425e+06  3.920784e+06      0.00
# pk_cid              5962924.0  1.234930e+06  1.623020e+05  15891.00
# region_code         5960660.0  2.581440e+01  1.359566e+01      1.00
# age                 5962924.0  2.976042e+01  1.198038e+01      2.00
# salary              4421820.0  1.155833e+05  2.000066e+05   1202.73
# Unnamed: 0           240773.0  1.203860e+05  6.950532e+04      0.00
# pk_sale              240773.0  1.270520e+05  6.950532e+04   6666.00
# cid                  240773.0  1.363934e+06  1.751721e+05  15891.00
# product_ID           240773.0  3.945408e+03  1.632822e+03   1119.00
# net_margin           240773.0  6.068782e+02  1.735806e+03     25.00
# Unnamed: 0               13.0  6.000000e+00  3.894440e+00      0.00
# pk_product_ID            13.0  3.614538e+03  2.564251e+03   1119.00
#
#                              25%         50%          75%          max  \
# Unnamed: 0          4.240386e+06  7499346.50  10201422.25  13647308.00
# pk_cid              1.112532e+06  1231097.00   1352339.00   1553689.00
# active_customer     0.000000e+00        0.00         1.00         1.00
# Unnamed: 0          4.240386e+06  7499346.50  10201422.25  13647308.00
# pk_cid              1.112532e+06  1231097.00   1352339.00   1553689.00
# short_term_deposit  0.000000e+00        0.00         0.00         1.00
# loans               0.000000e+00        0.00         0.00         1.00
# mortgage            0.000000e+00        0.00         0.00         1.00
# funds               0.000000e+00        0.00         0.00         1.00
# securities          0.000000e+00        0.00         0.00         1.00
# long_term_deposit   0.000000e+00        0.00         0.00         1.00
# em_account_pp       0.000000e+00        0.00         0.00         0.00
# credit_card         0.000000e+00        0.00         0.00         1.00
# payroll             0.000000e+00        0.00         0.00         1.00
# pension_plan        0.000000e+00        0.00         0.00         1.00
# payroll_account     0.000000e+00        0.00         0.00         1.00
# emc_account         0.000000e+00        0.00         0.00         1.00
# debit_card          0.000000e+00        0.00         0.00         1.00
# em_account_p        0.000000e+00        0.00         0.00         1.00
# em_acount           0.000000e+00        1.00         1.00         1.00
# Unnamed: 0          4.240386e+06  7499346.50  10201422.25  13647308.00
# pk_cid              1.112532e+06  1231097.00   1352339.00   1553689.00
# region_code         1.300000e+01       28.00        36.00        52.00
# age                 2.200000e+01       25.00        34.00       105.00
# salary              6.141532e+04    88441.47    131309.22  28894395.51
# Unnamed: 0          6.019300e+04   120386.00    180579.00    240772.00
# pk_sale             6.685900e+04   127052.00    187245.00    247438.00
# cid                 1.301012e+06  1409253.00   1475320.00   1553571.00
# product_ID          2.312000e+03     4657.00      4657.00      9001.00
# net_margin          6.140000e+01       69.10        79.20     18466.40
# Unnamed: 0          3.000000e+00        6.00         9.00        12.00
# pk_product_ID       2.235000e+03     2336.00      4033.00      9001.00
#
#                                        DataFrame
# Unnamed: 0          customer_commercial_activity
# pk_cid              customer_commercial_activity
# active_customer     customer_commercial_activity
# Unnamed: 0                     customer_products
# pk_cid                         customer_products
# short_term_deposit             customer_products
# loans                          customer_products
# mortgage                       customer_products
# funds                          customer_products
# securities                     customer_products
# long_term_deposit              customer_products
# em_account_pp                  customer_products
# credit_card                    customer_products
# payroll                        customer_products
# pension_plan                   customer_products
# payroll_account                customer_products
# emc_account                    customer_products
# debit_card                     customer_products
# em_account_p                   customer_products
# em_acount                      customer_products
# Unnamed: 0            customer_sociodemographics
# pk_cid                customer_sociodemographics
# region_code           customer_sociodemographics
# age                   customer_sociodemographics
# salary                customer_sociodemographics
# Unnamed: 0                                 sales
# pk_sale                                    sales
# cid                                        sales
# product_ID                                 sales
# net_margin                                 sales
# Unnamed: 0                   product_description
# pk_product_ID                product_description

# %%
def describe_cat(dataframes):
    df_descriptions = pd.DataFrame()

    for name, df in dataframes.items():
        description = df.describe(exclude = np.number).T
        description['DataFrame'] = name
        df_descriptions = pd.concat([df_descriptions, description])

    return df_descriptions

# %%
describe_cat(df_juntos)
# Out:
#                   count unique                 top     freq  \
# pk_partition    5962924     17             2019-05   442995
# entry_date      5962924     53             2016-10   382473
# entry_channel   5829891     68                 KHE  3113947
# segment         5828980      3  03 - UNIVERSITARIO  3900166
# pk_partition    5962924     17             2019-05   442995
# pk_partition    5962924     17             2019-05   442995
# country_id      5962924     41                  ES  5960672
# gender          5962899      2                   H  3087502
# deceased        5962924      2                   N  5961849
# month_sale       240773     16          2018-10-01    27693
# product_desc         13     13           em_acount        1
# family_product       13      5             account        4
#
#                                    DataFrame
# pk_partition    customer_commercial_activity
# entry_date      customer_commercial_activity
# entry_channel   customer_commercial_activity
# segment         customer_commercial_activity
# pk_partition               customer_products
# pk_partition      customer_sociodemographics
# country_id        customer_sociodemographics
# gender            customer_sociodemographics
# deceased          customer_sociodemographics
# month_sale                             sales
# product_desc             product_description
# family_product           product_description

# %% [markdown]
# ### 1.1 Nulos y duplicados en todos los DataFrames

# %%
def info_nulls(*dataframes):
  for df in dataframes:
    print(f"{df.name} - Valores nulos:")
    print(df.isnull().sum())
    print("\n")

# %%
info_nulls(customer_commercial_activity, customer_products, customer_sociodemographics, sales, product_description)
# Out:
# customer_commercial_activity - Valores nulos:
# Unnamed: 0              0
# pk_cid                  0
# pk_partition            0
# entry_date              0
# entry_channel      133033
# active_customer         0
# segment            133944
# dtype: int64
#
#
# customer_products - Valores nulos:
# Unnamed: 0             0
# pk_cid                 0
# pk_partition           0
# short_term_deposit     0
# loans                  0
# mortgage               0
# funds                  0
# securities             0
# long_term_deposit      0
# em_account_pp          0
# credit_card            0
# payroll               61
# pension_plan          61
# payroll_account        0
# emc_account            0
# debit_card             0
# em_account_p           0
# em_acount              0
# dtype: int64
#
#
# customer_sociodemographics - Valores nulos:
# Unnamed: 0            0
# pk_cid                0
# pk_partition          0
# country_id            0
# region_code        2264
# gender               25
# age                   0
# deceased              0
# salary          1541104
# dtype: int64
#
#
# sales - Valores nulos:
# Unnamed: 0    0
# pk_sale       0
# cid           0
# month_sale    0
# product_ID    0
# net_margin    0
# dtype: int64
#
#
# product_description - Valores nulos:
# Unnamed: 0        0
# pk_product_ID     0
# product_desc      0
# family_product    0
# dtype: int64

# %%
def info_duplicate(*dataframes):
  for df in dataframes:
    print(f"{df.name} - Filas duplicadas: {df.duplicated().any()}")
    print("\n")

# %%
info_duplicate(customer_commercial_activity, customer_products, customer_sociodemographics, sales, product_description)
# Out:
# customer_commercial_activity - Filas duplicadas: False
#
#
# customer_products - Filas duplicadas: False
#
#
# customer_sociodemographics - Filas duplicadas: False
#
#
# sales - Filas duplicadas: False
#
#
# product_description - Filas duplicadas: False

# %% [markdown]
# # **2. Data Preparation**

# %% [markdown]
# ##Creamos una copia de seguridad

# %%
customer_commercial_activity1 = customer_commercial_activity.copy()
customer_products1 = customer_products.copy()
customer_sociodemographics1 = customer_sociodemographics.copy()
sales1 = sales.copy()
product_description1 = product_description.copy()

# %%
customer_commercial_activity1.name = 'customer_commercial_activity1'
customer_products1.name = 'customer_products1'
customer_sociodemographics1.name = 'customer_sociodemographics1'
sales1.name = 'sales1'
product_description1.name = 'product_description1'

# %% [markdown]
# ##Borramos Unnamed: 0

# %%
def borrar_col(column, *dataframes):
  for df in dataframes:
    if column in df.columns:
      df.drop(column, axis=1, inplace=True)
  return "Se borró la columna"

# %%
borrar_col("Unnamed: 0", customer_commercial_activity1, customer_products1, customer_sociodemographics1, sales1, product_description1)
# Out:
# 'Se borró la columna'

# %%
customer_commercial_activity1
# Out:
#           pk_cid pk_partition entry_date entry_channel  active_customer  \
# 0        1375586      2018-01    2018-01           KHL              1.0
# 1        1050611      2018-01    2015-08           KHE              0.0
# 2        1050612      2018-01    2015-08           KHE              0.0
# 3        1050613      2018-01    2015-08           KHD              0.0
# 4        1050614      2018-01    2015-08           KHE              1.0
# ...          ...          ...        ...           ...              ...
# 5962919  1166765      2019-05    2016-08           KHE              0.0
# 5962920  1166764      2019-05    2016-08           KHE              0.0
# 5962921  1166763      2019-05    2016-08           KHE              1.0
# 5962922  1166789      2019-05    2016-08           KHE              0.0
# 5962923  1550586      2019-05    2019-05           NaN              1.0
#
#                     segment
# 0         02 - PARTICULARES
# 1        03 - UNIVERSITARIO
# 2        03 - UNIVERSITARIO
# 3        03 - UNIVERSITARIO
# 4        03 - UNIVERSITARIO
# ...                     ...
# 5962919  03 - UNIVERSITARIO
# 5962920  03 - UNIVERSITARIO
# 5962921   02 - PARTICULARES
# 5962922  03 - UNIVERSITARIO
# 5962923                 NaN
#
# [5962924 rows x 6 columns]

# %% [markdown]
# ## 2.1 customer_commercial_activity

# %% [markdown]
# ### Analizamos *customer_commercial_activity*

# %%
def mostrar_informacion_dataframe(df):
  print(f"Información de: {df.name}")
  df.info()

  for columna in df.columns:
        print("\nRecuento de valores únicos en la columna:")
        print(df[columna].value_counts())
        print("\n")
        print("\nRecuento de valores nulos en la columna:")
        print(df[columna].isnull().sum())
        print("\n")

# %%
mostrar_informacion_dataframe(customer_commercial_activity1)
# Out:
# Información de: customer_commercial_activity1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   pk_cid           int64
#  1   pk_partition     object
#  2   entry_date       object
#  3   entry_channel    object
#  4   active_customer  float64
#  5   segment          object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 273.0+ MB
#
# Recuento de valores únicos en la columna:
# 1375586    17
# 1328781    17
# 1328783    17
# 1328784    17
# 1328786    17
#            ..
# 1521045     1
# 1545224     1
# 1470941     1
# 1521049     1
# 1550586     1
# Name: pk_cid, Length: 456373, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2019-05    442995
# 2019-04    439627
# 2019-03    436183
# 2019-02    431727
# 2019-01    426875
# 2018-12    422481
# 2018-11    416387
# 2018-10    402300
# 2018-09    375323
# 2018-08    352922
# 2018-07    339339
# 2018-06    252104
# 2018-05    249926
# 2018-04    247463
# 2018-03    245258
# 2018-02    242521
# 2018-01    239493
# Name: pk_partition, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2016-10    382473
# 2017-10    340613
# 2015-10    310295
# 2017-09    294752
# 2017-07    267173
# 2016-08    252704
# 2015-08    221984
# 2015-07    220941
# 2017-11    217751
# 2015-09    217174
# 2018-10    216947
# 2015-11    210687
# 2016-09    206107
# 2018-09    202262
# 2016-07    189225
# 2016-11    188601
# 2018-07    178215
# 2017-08    162534
# 2018-08    138420
# 2017-12    123456
# 2018-11    103073
# 2016-12     89423
# 2015-12     82347
# 2017-01     65539
# 2018-02     61283
# 2018-01     59721
# 2017-06     54925
# 2018-03     51022
# 2016-01     50830
# 2017-02     50561
# 2017-03     50268
# 2017-05     50165
# 2017-04     47729
# 2018-04     43480
# 2018-12     41244
# 2018-05     40563
# 2015-05     40001
# 2016-04     35682
# 2018-06     35590
# 2015-03     35322
# 2015-04     34706
# 2016-05     33234
# 2015-06     33062
# 2019-01     32640
# 2015-02     30626
# 2016-06     30095
# 2015-01     29646
# 2016-02     29552
# 2016-03     27329
# 2019-02     23533
# 2019-03     14434
# 2019-04      8602
# 2019-05      4383
# Name: entry_date, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# KHE    3113947
# KFC     890620
# KHQ     590280
# KAT     416084
# KHK     230197
#         ...
# KEJ          8
# KHS          5
# KDA          2
# KFP          2
# KDS          1
# Name: entry_channel, Length: 68, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 133033
#
#
#
# Recuento de valores únicos en la columna:
# 0.0    3557573
# 1.0    2405351
# Name: active_customer, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 03 - UNIVERSITARIO    3900166
# 02 - PARTICULARES     1830875
# 01 - TOP                97939
# Name: segment, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 133944

# %% [markdown]
# Análisis:
#
#
# *   pk_cid: cambiar a object. - debemos evaluar porque se tienen hasta 17 datos por pk_cid. revisar si se borra
# *   pk_partition: es una fecha, cambiar a datetime64 (%Y, %m)
# *   entry_date: es una fecha, cambiar a datetime64 (%Y, %m)
# *   entry_channel: tiene valores nulos (133033), completar con (no_info)
# *   active_customer: boolean, cambiar a int8 (para menor almacenaje)
# *   segment: ok, tiene valores nulos (133944), completar con (no_indica)

# %% [markdown]
# #### pk_cid

# %%
customer_commercial_activity1["pk_cid"] = customer_commercial_activity1["pk_cid"].astype(str)

# %%
customer_commercial_activity1[customer_commercial_activity1["pk_cid"] == "1375586"]
# Out:
#           pk_cid pk_partition entry_date entry_channel  active_customer  \
# 0        1375586      2018-01    2018-01           KHL              1.0
# 346322   1375586      2018-02    2018-01           KHL              1.0
# 592407   1375586      2018-03    2018-01           KHL              1.0
# 831104   1375586      2018-04    2018-01           KHL              1.0
# 1108457  1375586      2018-05    2018-01           KHL              1.0
# 1357280  1375586      2018-06    2018-01           KHL              1.0
# 1791360  1375586      2018-07    2018-01           KHL              1.0
# 1988936  1375586      2018-08    2018-01           KHL              0.0
# 2487565  1375586      2018-09    2018-01           KHL              0.0
# 2753984  1375586      2018-10    2018-01           KHL              0.0
# 3156714  1375586      2018-11    2018-01           KHL              0.0
# 3719100  1375586      2018-12    2018-01           KHL              0.0
# 3950225  1375586      2019-01    2018-01           KHL              0.0
# 4436665  1375586      2019-02    2018-01           KHL              0.0
# 4840281  1375586      2019-03    2018-01           KHL              1.0
# 5336125  1375586      2019-04    2018-01           KHL              0.0
# 5569690  1375586      2019-05    2018-01           KHL              1.0
#
#                    segment
# 0        02 - PARTICULARES
# 346322   02 - PARTICULARES
# 592407   02 - PARTICULARES
# 831104   02 - PARTICULARES
# 1108457  02 - PARTICULARES
# 1357280  02 - PARTICULARES
# 1791360  02 - PARTICULARES
# 1988936  02 - PARTICULARES
# 2487565  02 - PARTICULARES
# 2753984  02 - PARTICULARES
# 3156714  02 - PARTICULARES
# 3719100  02 - PARTICULARES
# 3950225  02 - PARTICULARES
# 4436665  02 - PARTICULARES
# 4840281  02 - PARTICULARES
# 5336125  02 - PARTICULARES
# 5569690  02 - PARTICULARES

# %% [markdown]
# Comentario: El pk_cid, se repite porque hay clientes que se encuentran activos por varios meses, siendo el pk_partition los meses que se encuentra activo

# %%
customer_commercial_activity1["pk_cid"].nunique()
# Out:
# 456373

# %% [markdown]
# #### pk_partition

# %%
customer_commercial_activity1["pk_partition"] = pd.to_datetime(customer_commercial_activity1["pk_partition"], format= "%Y-%m")

# %% [markdown]
# ####entry_date

# %%
customer_commercial_activity1["entry_date"] = pd.to_datetime(customer_commercial_activity1["entry_date"], format= "%Y-%m")

# %% [markdown]
# ####entry_channel

# %%
def valores_nulos(df, columna, relleno):
  df[columna].fillna(relleno, inplace=True)
  return df[columna].isnull().sum()

# %%
valores_nulos(customer_commercial_activity1, "entry_channel", "No_data")
# Out:
# 0

# %% [markdown]
# ####active_customer

# %%
customer_commercial_activity1["active_customer"] = customer_commercial_activity1["active_customer"].astype("int8")

# %% [markdown]
# ####segment

# %%
valores_nulos(customer_commercial_activity1, "segment", "no_indica")
# Out:
# 0

# %%
mostrar_informacion_dataframe(customer_commercial_activity1)
# Out:
# Información de: customer_commercial_activity1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   pk_cid           object
#  1   pk_partition     datetime64[ns]
#  2   entry_date       datetime64[ns]
#  3   entry_channel    object
#  4   active_customer  int8
#  5   segment          object
# dtypes: datetime64[ns](2), int8(1), object(3)
# memory usage: 233.2+ MB
#
# Recuento de valores únicos en la columna:
# 1375586    17
# 1328781    17
# 1328783    17
# 1328784    17
# 1328786    17
#            ..
# 1521045     1
# 1545224     1
# 1470941     1
# 1521049     1
# 1550586     1
# Name: pk_cid, Length: 456373, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2019-05-01    442995
# 2019-04-01    439627
# 2019-03-01    436183
# 2019-02-01    431727
# 2019-01-01    426875
# 2018-12-01    422481
# 2018-11-01    416387
# 2018-10-01    402300
# 2018-09-01    375323
# 2018-08-01    352922
# 2018-07-01    339339
# 2018-06-01    252104
# 2018-05-01    249926
# 2018-04-01    247463
# 2018-03-01    245258
# 2018-02-01    242521
# 2018-01-01    239493
# Name: pk_partition, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2016-10-01    382473
# 2017-10-01    340613
# 2015-10-01    310295
# 2017-09-01    294752
# 2017-07-01    267173
# 2016-08-01    252704
# 2015-08-01    221984
# 2015-07-01    220941
# 2017-11-01    217751
# 2015-09-01    217174
# 2018-10-01    216947
# 2015-11-01    210687
# 2016-09-01    206107
# 2018-09-01    202262
# 2016-07-01    189225
# 2016-11-01    188601
# 2018-07-01    178215
# 2017-08-01    162534
# 2018-08-01    138420
# 2017-12-01    123456
# 2018-11-01    103073
# 2016-12-01     89423
# 2015-12-01     82347
# 2017-01-01     65539
# 2018-02-01     61283
# 2018-01-01     59721
# 2017-06-01     54925
# 2018-03-01     51022
# 2016-01-01     50830
# 2017-02-01     50561
# 2017-03-01     50268
# 2017-05-01     50165
# 2017-04-01     47729
# 2018-04-01     43480
# 2018-12-01     41244
# 2018-05-01     40563
# 2015-05-01     40001
# 2016-04-01     35682
# 2018-06-01     35590
# 2015-03-01     35322
# 2015-04-01     34706
# 2016-05-01     33234
# 2015-06-01     33062
# 2019-01-01     32640
# 2015-02-01     30626
# 2016-06-01     30095
# 2015-01-01     29646
# 2016-02-01     29552
# 2016-03-01     27329
# 2019-02-01     23533
# 2019-03-01     14434
# 2019-04-01      8602
# 2019-05-01      4383
# Name: entry_date, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# KHE    3113947
# KFC     890620
# KHQ     590280
# KAT     416084
# KHK     230197
#         ...
# KEJ          8
# KHS          5
# KDA          2
# KFP          2
# KDS          1
# Name: entry_channel, Length: 69, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    3557573
# 1    2405351
# Name: active_customer, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 03 - UNIVERSITARIO    3900166
# 02 - PARTICULARES     1830875
# no_indica              133944
# 01 - TOP                97939
# Name: segment, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0

# %% [markdown]
# ## 2.2 customer_products

# %% [markdown]
# ###Analizamos *customer_products*

# %%
mostrar_informacion_dataframe(customer_products1)
# Out:
# Información de: customer_products1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 17 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   pk_cid              int64
#  1   pk_partition        object
#  2   short_term_deposit  int64
#  3   loans               int64
#  4   mortgage            int64
#  5   funds               int64
#  6   securities          int64
#  7   long_term_deposit   int64
#  8   em_account_pp       int64
#  9   credit_card         int64
#  10  payroll             float64
#  11  pension_plan        float64
#  12  payroll_account     int64
#  13  emc_account         int64
#  14  debit_card          int64
#  15  em_account_p        int64
#  16  em_acount           int64
# dtypes: float64(2), int64(14), object(1)
# memory usage: 773.4+ MB
#
# Recuento de valores únicos en la columna:
# 1375586    17
# 1328781    17
# 1328783    17
# 1328784    17
# 1328786    17
#            ..
# 1521045     1
# 1545224     1
# 1470941     1
# 1521049     1
# 1550586     1
# Name: pk_cid, Length: 456373, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2019-05    442995
# 2019-04    439627
# 2019-03    436183
# 2019-02    431727
# 2019-01    426875
# 2018-12    422481
# 2018-11    416387
# 2018-10    402300
# 2018-09    375323
# 2018-08    352922
# 2018-07    339339
# 2018-06    252104
# 2018-05    249926
# 2018-04    247463
# 2018-03    245258
# 2018-02    242521
# 2018-01    239493
# Name: pk_partition, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5947530
# 1      15394
# Name: short_term_deposit, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5962456
# 1        468
# Name: loans, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5962600
# 1        324
# Name: mortgage, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5942825
# 1      20099
# Name: funds, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5940791
# 1      22133
# Name: securities, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5862264
# 1     100660
# Name: long_term_deposit, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5962924
# Name: em_account_pp, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5892058
# 1      70866
# Name: credit_card, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0.0    5757076
# 1.0     205787
# Name: payroll, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 61
#
#
#
# Recuento de valores únicos en la columna:
# 0.0    5745061
# 1.0     217802
# Name: pension_plan, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 61
#
#
#
# Recuento de valores únicos en la columna:
# 0    5633504
# 1     329420
# Name: payroll_account, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5635963
# 1     326961
# Name: emc_account, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5399956
# 1     562968
# Name: debit_card, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5962890
# 1         34
# Name: em_account_p, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 1    4381602
# 0    1581322
# Name: em_acount, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0

# %% [markdown]
# Análisis:
#
#
# *   pk_cid: cambiar a object.
# *   pk_partition: es una fecha, cambiar a datetime64 (%Y, %m)
# *   Hacer una lista con las columnas de productos y cambiarlas a "int8", los nulos se consideran como 0 porque no tenemos información de si cuentan con ese producto o no. (deben ser booleans)

# %% [markdown]
# #### pk_cid

# %%
customer_products1["pk_cid"] = customer_products1["pk_cid"].astype(str)

# %% [markdown]
# ####pk_partition

# %%
customer_products1["pk_partition"] = pd.to_datetime(customer_products1["pk_partition"], format= "%Y-%m")

# %% [markdown]
# ####Productos

# %%
customer_products1.columns.tolist()
# Out:
# ['pk_cid',
#  'pk_partition',
#  'short_term_deposit',
#  'loans',
#  'mortgage',
#  'funds',
#  'securities',
#  'long_term_deposit',
#  'em_account_pp',
#  'credit_card',
#  'payroll',
#  'pension_plan',
#  'payroll_account',
#  'emc_account',
#  'debit_card',
#  'em_account_p',
#  'em_acount']

# %%
lista_productos = [ 'short_term_deposit',
 'loans',
 'mortgage',
 'funds',
 'securities',
 'long_term_deposit',
 'em_account_pp',
 'credit_card',
 'payroll',
 'pension_plan',
 'payroll_account',
 'emc_account',
 'debit_card',
 'em_account_p',
 'em_acount']

# %%
def cambiar_productos (df, columnas):
  df[columnas] = df[columnas].replace([np.nan, np.inf, -np.inf], 0)
  df[columnas] = df[columnas].astype("int8")
  return df.info()

# %%
cambiar_productos (customer_products1, lista_productos)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 17 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   pk_cid              object
#  1   pk_partition        datetime64[ns]
#  2   short_term_deposit  int8
#  3   loans               int8
#  4   mortgage            int8
#  5   funds               int8
#  6   securities          int8
#  7   long_term_deposit   int8
#  8   em_account_pp       int8
#  9   credit_card         int8
#  10  payroll             int8
#  11  pension_plan        int8
#  12  payroll_account     int8
#  13  emc_account         int8
#  14  debit_card          int8
#  15  em_account_p        int8
#  16  em_acount           int8
# dtypes: datetime64[ns](1), int8(15), object(1)
# memory usage: 176.3+ MB

# %%
mostrar_informacion_dataframe(customer_products1)
# Out:
# Información de: customer_products1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 17 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   pk_cid              object
#  1   pk_partition        datetime64[ns]
#  2   short_term_deposit  int8
#  3   loans               int8
#  4   mortgage            int8
#  5   funds               int8
#  6   securities          int8
#  7   long_term_deposit   int8
#  8   em_account_pp       int8
#  9   credit_card         int8
#  10  payroll             int8
#  11  pension_plan        int8
#  12  payroll_account     int8
#  13  emc_account         int8
#  14  debit_card          int8
#  15  em_account_p        int8
#  16  em_acount           int8
# dtypes: datetime64[ns](1), int8(15), object(1)
# memory usage: 176.3+ MB
#
# Recuento de valores únicos en la columna:
# 1375586    17
# 1328781    17
# 1328783    17
# 1328784    17
# 1328786    17
#            ..
# 1521045     1
# 1545224     1
# 1470941     1
# 1521049     1
# 1550586     1
# Name: pk_cid, Length: 456373, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2019-05-01    442995
# 2019-04-01    439627
# 2019-03-01    436183
# 2019-02-01    431727
# 2019-01-01    426875
# 2018-12-01    422481
# 2018-11-01    416387
# 2018-10-01    402300
# 2018-09-01    375323
# 2018-08-01    352922
# 2018-07-01    339339
# 2018-06-01    252104
# 2018-05-01    249926
# 2018-04-01    247463
# 2018-03-01    245258
# 2018-02-01    242521
# 2018-01-01    239493
# Name: pk_partition, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5947530
# 1      15394
# Name: short_term_deposit, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5962456
# 1        468
# Name: loans, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5962600
# 1        324
# Name: mortgage, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5942825
# 1      20099
# Name: funds, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5940791
# 1      22133
# Name: securities, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5862264
# 1     100660
# Name: long_term_deposit, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5962924
# Name: em_account_pp, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5892058
# 1      70866
# Name: credit_card, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5757137
# 1     205787
# Name: payroll, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5745122
# 1     217802
# Name: pension_plan, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5633504
# 1     329420
# Name: payroll_account, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5635963
# 1     326961
# Name: emc_account, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5399956
# 1     562968
# Name: debit_card, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 0    5962890
# 1         34
# Name: em_account_p, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 1    4381602
# 0    1581322
# Name: em_acount, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0

# %%
#vamos a esperar para eliminar "em_account_pp" que no tiene información

# %%
stock_mes = customer_products1.groupby('pk_partition').sum(numeric_only=True)
stock_mes
# Out:
#               short_term_deposit  loans  mortgage  funds  securities  \
# pk_partition
# 2018-01-01                   883     19        15    786         932
# 2018-02-01                  1343     19        15    872         965
# 2018-03-01                  1664     23        17    969         965
# 2018-04-01                  1740     24        17   1084         983
# 2018-05-01                  1455     27        18   1145        1012
# 2018-06-01                  1244     27        19   1159        1019
# 2018-07-01                  1282     28        20   1172        1053
# 2018-08-01                  1335     29        20   1219        1133
# 2018-09-01                  1386     31        20   1237        1201
# 2018-10-01                  1374     33        19   1249        1348
# 2018-11-01                  1018     32        19   1282        1360
# 2018-12-01                   528     30        19   1322        1420
# 2019-01-01                   125     28        20   1330        1655
# 2019-02-01                    11     29        20   1316        1747
# 2019-03-01                     2     29        20   1322        1769
# 2019-04-01                     2     30        23   1320        1782
# 2019-05-01                     2     30        23   1315        1789
#
#               long_term_deposit  em_account_pp  credit_card  payroll  \
# pk_partition
# 2018-01-01                 4884              0         3325     8145
# 2018-02-01                 4956              0         3282     8889
# 2018-03-01                 4965              0         3511     9735
# 2018-04-01                 5107              0         3725     9905
# 2018-05-01                 5356              0         3797     9994
# 2018-06-01                 5588              0         4002    10946
# 2018-07-01                 5796              0         4137    11888
# 2018-08-01                 5923              0         4206    11383
# 2018-09-01                 6158              0         4289    11850
# 2018-10-01                 6380              0         4385    12454
# 2018-11-01                 6447              0         4512    13032
# 2018-12-01                 6749              0         4536    14452
# 2019-01-01                 6659              0         4493    12058
# 2019-02-01                 6658              0         4542    14378
# 2019-03-01                 6537              0         4576    15114
# 2019-04-01                 6368              0         4747    15231
# 2019-05-01                 6129              0         4801    16333
#
#               pension_plan  payroll_account  emc_account  debit_card  \
# pk_partition
# 2018-01-01            8835            13478        15320       24696
# 2018-02-01            9496            14246        15827       25448
# 2018-03-01            9882            14989        16428       27046
# 2018-04-01           10560            15825        16947       27764
# 2018-05-01           10148            16697        17569       27911
# 2018-06-01           11635            15540        17950       28828
# 2018-07-01           12779            16916        18185       29578
# 2018-08-01           12126            18118        18333       29205
# 2018-09-01           12624            18862        18618       31684
# 2018-10-01           13223            19945        18844       34372
# 2018-11-01           13818            21437        19494       35466
# 2018-12-01           15324            21359        20043       37430
# 2019-01-01           12538            22324        20921       37350
# 2019-02-01           15265            23264        21796       39399
# 2019-03-01           15976            24390        22480       41390
# 2019-04-01           16220            25501        23455       42140
# 2019-05-01           17353            26529        24751       43261
#
#               em_account_p  em_acount
# pk_partition
# 2018-01-01               2     215293
# 2018-02-01               2     217098
# 2018-03-01               2     218683
# 2018-04-01               2     219816
# 2018-05-01               2     221291
# 2018-06-01               2     224328
# 2018-07-01               2     234324
# 2018-08-01               2     245980
# 2018-09-01               2     261210
# 2018-10-01               2     277707
# 2018-11-01               2     284900
# 2018-12-01               2     288928
# 2019-01-01               2     291786
# 2019-02-01               2     292988
# 2019-03-01               2     295046
# 2019-04-01               2     295844
# 2019-05-01               2     296380

# %% [markdown]
# ## 2.3 customer_sociodemographics

# %% [markdown]
# ### Analizamos customer_sociodemographics

# %%
mostrar_informacion_dataframe(customer_sociodemographics1)
# Out:
# Información de: customer_sociodemographics1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   pk_cid        int64
#  1   pk_partition  object
#  2   country_id    object
#  3   region_code   float64
#  4   gender        object
#  5   age           int64
#  6   deceased      object
#  7   salary        float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 363.9+ MB
#
# Recuento de valores únicos en la columna:
# 1375586    17
# 1328781    17
# 1328783    17
# 1328784    17
# 1328786    17
#            ..
# 1521045     1
# 1545224     1
# 1470941     1
# 1521049     1
# 1550586     1
# Name: pk_cid, Length: 456373, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2019-05    442995
# 2019-04    439627
# 2019-03    436183
# 2019-02    431727
# 2019-01    426875
# 2018-12    422481
# 2018-11    416387
# 2018-10    402300
# 2018-09    375323
# 2018-08    352922
# 2018-07    339339
# 2018-06    252104
# 2018-05    249926
# 2018-04    247463
# 2018-03    245258
# 2018-02    242521
# 2018-01    239493
# Name: pk_partition, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# ES    5960672
# GB        441
# FR        225
# DE        199
# US        195
# CH        194
# BR         87
# BE         81
# VE         79
# IE         68
# MX         58
# AT         51
# AR         51
# PL         49
# IT         45
# MA         34
# CL         30
# CN         28
# CA         22
# LU         17
# ET         17
# QA         17
# CI         17
# SA         17
# CM         17
# SN         17
# MR         17
# NO         17
# RU         17
# CO         17
# GA         17
# GT         17
# DO         17
# SE         16
# DJ         11
# PT         11
# JM         11
# RO          9
# HU          8
# DZ          7
# PE          4
# Name: country_id, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 28.0    1185757
# 8.0      600362
# 46.0     358142
# 30.0     296856
# 41.0     290447
# 15.0     254891
# 29.0     187911
# 36.0     175850
# 3.0      171358
# 11.0     160894
# 33.0     134562
# 50.0     132983
# 6.0      122587
# 35.0     121982
# 47.0     116948
# 18.0     102789
# 45.0     102328
# 37.0      92538
# 10.0      83283
# 14.0      75405
# 2.0       72071
# 21.0      72037
# 13.0      70092
# 39.0      69589
# 12.0      68709
# 7.0       62436
# 32.0      54639
# 27.0      52783
# 43.0      51782
# 17.0      50749
# 9.0       47746
# 25.0      46887
# 16.0      36094
# 24.0      35426
# 48.0      35256
# 26.0      34790
# 4.0       32680
# 31.0      31241
# 49.0      30965
# 23.0      30955
# 38.0      29001
# 34.0      27545
# 19.0      26762
# 40.0      21658
# 5.0       21300
# 22.0      21112
# 20.0      18833
# 1.0       12999
# 44.0      12616
# 42.0       8500
# 51.0       2896
# 52.0       2638
# Name: region_code, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 2264
#
#
#
# Recuento de valores únicos en la columna:
# H    3087502
# V    2875397
# Name: gender, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 25
#
#
#
# Recuento de valores únicos en la columna:
# 22     727134
# 23     702127
# 21     667762
# 20     413568
# 24     408569
#         ...
# 101        91
# 102        65
# 103        25
# 104        12
# 105         8
# Name: age, Length: 104, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# N    5961849
# S       1075
# Name: deceased, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 451931.22    709
# 288997.44    546
# 135522.15    466
# 128318.52    458
# 104563.80    436
#             ...
# 178580.58      1
# 140411.13      1
# 73880.40       1
# 78719.40       1
# 94128.15       1
# Name: salary, Length: 257654, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 1541104

# %% [markdown]
# Análisis:
#
#
# *   pk_cid: cambiar a object.
# *   pk_partition: es una fecha, cambiar a datetime64 (%Y, %m)
# *   country_id: ok
# *   region_code: tiene nulos, rellenar con "no_data"
# *   gender: tiene nulos, rellenar con "no_data"
# *   age: cambiar a int8
# *   decease: boolean, ok
# *   salary: cambiar a "int"

# %% [markdown]
# #### pk_cid

# %%
customer_sociodemographics1["pk_cid"] = customer_sociodemographics1["pk_cid"].astype(str)

# %% [markdown]
# ####pk_partition

# %%
customer_sociodemographics1["pk_partition"] = pd.to_datetime(customer_sociodemographics1["pk_partition"], format= "%Y-%m")

# %% [markdown]
# ####region_code

# %%
valores_nulos(customer_sociodemographics1, "region_code", 0)
# Out:
# 0

# %%
customer_sociodemographics1["region_code"] = customer_sociodemographics1["region_code"].astype(str)

# %% [markdown]
# ####gender

# %%
valores_nulos(customer_sociodemographics1, "gender", "no_data")
# Out:
# 0

# %%
customer_sociodemographics1["gender"] = customer_sociodemographics1["gender"].replace("H", "M")
customer_sociodemographics1["gender"] = customer_sociodemographics1["gender"].replace("V", "H")

# %% [markdown]
# ####age

# %%
customer_sociodemographics1["age"] = customer_sociodemographics1["age"].astype("int8")

# %% [markdown]
# ####salary

# %%
customer_sociodemographics1["salary"] = customer_sociodemographics1["salary"].round()

# %%
# Para tratar los nulos de Salary, primero conoceremos más de la variable. R

salary_no_null = customer_sociodemographics1.dropna(subset=['salary'])

salary_by_region = salary_no_null.groupby('region_code')['salary'].agg(
    mean_salary= 'mean',
    max_salary= 'max',
    min_salary= 'min',
    median_salary= 'median'
)
salary_by_region.T
# Out:
# region_code              0.0       1.0          10.0          11.0  \
# mean_salary    175569.405405  107098.0  7.351092e+04  9.468972e+04
# max_salary     385514.000000  253563.0  1.309035e+06  2.311469e+06
# min_salary      46884.000000   55271.0  5.130000e+03  8.346000e+03
# median_salary  114949.000000   74454.0  6.640600e+04  7.551400e+04
#
# region_code             12.0           13.0          14.0          15.0  \
# mean_salary     76509.490885   67375.639062  7.976911e+04  1.078846e+05
# max_salary     668527.000000  952513.000000  1.394465e+06  2.564976e+06
# min_salary      11933.000000    3732.000000  7.507000e+03  9.781000e+03
# median_salary   64852.000000   60829.000000  6.437100e+04  9.405400e+04
#
# region_code             16.0          17.0  ...           48.0          49.0  \
# mean_salary     70310.261291  1.458372e+05  ...  110240.885714  8.148438e+04
# max_salary     408454.000000  6.209401e+06  ...  160481.000000  1.536265e+06
# min_salary       8843.000000  1.868100e+04  ...   55588.000000  7.776000e+03
# median_salary   67615.000000  1.082300e+05  ...  108659.000000  7.341700e+04
#
# region_code             5.0          50.0          51.0          52.0  \
# mean_salary    7.727128e+04  1.080285e+05  2.109242e+05  1.649124e+05
# max_salary     2.768593e+06  8.516913e+06  4.082464e+06  1.949948e+06
# min_salary     7.290000e+03  9.788000e+03  3.343000e+04  3.443700e+04
# median_salary  6.760900e+04  9.679600e+04  1.241580e+05  1.136100e+05
#
# region_code              6.0           7.0           8.0           9.0
# mean_salary     69921.475043  1.531694e+05  1.568012e+05  9.545358e+04
# max_salary     594804.000000  1.571172e+07  5.752268e+06  1.446904e+06
# min_salary       7144.000000  6.698000e+03  7.983000e+03  1.115400e+04
# median_salary   60290.000000  1.167100e+05  1.246220e+05  8.768100e+04
#
# [4 rows x 53 columns]

# %%
#Utilizamos 'region_code', ya que la mayoría es de España y decidimos ponerle 0.0 a los nulos

# %%
salary_no_null[salary_no_null['region_code']=="0.0"]
# Out:
#           pk_cid pk_partition country_id region_code gender  age deceased  \
# 2193581  1250880   2018-09-01         RO         0.0      H   52        N
# 2875968  1250880   2018-10-01         RO         0.0      H   52        N
# 2976453  1440250   2018-11-01         DZ         0.0      H   39        N
# 3089135  1250880   2018-11-01         RO         0.0      H   52        N
# 3447353  1250880   2018-12-01         RO         0.0      H   52        N
# 3628803   670953   2018-12-01         GB         0.0      H   39        N
# 3650220  1440250   2018-12-01         DZ         0.0      H   39        N
# 3793909  1440250   2019-01-01         DZ         0.0      H   39        N
# 4067864  1250880   2019-01-01         RO         0.0      H   52        N
# 4103151   670953   2019-01-01         GB         0.0      H   40        N
# 4336605  1250880   2019-02-01         RO         0.0      H   52        N
# 4413077  1404595   2019-02-01         CH         0.0      M   40        N
# 4435535  1376996   2019-02-01         PE         0.0      H   37        N
# 4449613  1440250   2019-02-01         DZ         0.0      H   39        N
# 4479705   670953   2019-02-01         GB         0.0      H   40        N
# 4609369  1121325   2019-02-01         CA         0.0      H   49        N
# 4645990  1440250   2019-03-01         DZ         0.0      H   39        N
# 4675127  1404595   2019-03-01         CH         0.0      M   40        N
# 4802119  1250880   2019-03-01         RO         0.0      H   52        N
# 4844774  1376996   2019-03-01         PE         0.0      H   37        N
# 4887293   670953   2019-03-01         GB         0.0      H   40        N
# 4944394  1121325   2019-03-01         CA         0.0      H   49        N
# 5080396   670953   2019-04-01         GB         0.0      H   40        N
# 5154338  1121325   2019-04-01         CA         0.0      H   49        N
# 5179915  1078010   2019-04-01         CH         0.0      H   43        N
# 5311248  1404595   2019-04-01         CH         0.0      M   40        N
# 5336956  1376996   2019-04-01         PE         0.0      H   37        N
# 5398505  1440250   2019-04-01         DZ         0.0      H   39        N
# 5409324  1250880   2019-04-01         RO         0.0      H   52        N
# 5520009   670953   2019-05-01         GB         0.0      H   40        N
# 5564830  1404595   2019-05-01         CH         0.0      M   40        N
# 5568702  1376996   2019-05-01         PE         0.0      H   37        N
# 5572933  1371001   2019-05-01         CL         0.0      H   37        N
# 5711817  1440250   2019-05-01         DZ         0.0      H   39        N
# 5767237  1078010   2019-05-01         CH         0.0      H   43        N
# 5876254  1250880   2019-05-01         RO         0.0      H   52        N
# 5922695  1121325   2019-05-01         CA         0.0      H   49        N
#
#            salary
# 2193581  114949.0
# 2875968  114949.0
# 2976453  385514.0
# 3089135  114949.0
# 3447353  114949.0
# 3628803  111760.0
# 3650220  385514.0
# 3793909  385514.0
# 4067864  114949.0
# 4103151  111760.0
# 4336605  114949.0
# 4413077  229747.0
# 4435535  116770.0
# 4449613  385514.0
# 4479705  111760.0
# 4609369  110075.0
# 4645990  385514.0
# 4675127  229747.0
# 4802119  114949.0
# 4844774  116770.0
# 4887293  111760.0
# 4944394  110075.0
# 5080396  111760.0
# 5154338  110075.0
# 5179915   46884.0
# 5311248  229747.0
# 5336956  116770.0
# 5398505  385514.0
# 5409324  114949.0
# 5520009  111760.0
# 5564830  229747.0
# 5568702  116770.0
# 5572933  172233.0
# 5711817  385514.0
# 5767237   46884.0
# 5876254  114949.0
# 5922695  110075.0

# %%
median_by_region = salary_by_region['median_salary']
customer_sociodemographics1['salary'] = customer_sociodemographics1.apply(lambda row: median_by_region[row['region_code']] if pd.isnull(row['salary']) else row['salary'], axis=1)

# %%
customer_sociodemographics1.head(20)
# Out:
#      pk_cid pk_partition country_id region_code gender  age deceased    salary
# 0   1375586   2018-01-01         ES        29.0      M   35        N   87218.0
# 1   1050611   2018-01-01         ES        13.0      H   23        N   35549.0
# 2   1050612   2018-01-01         ES        13.0      H   23        N  122179.0
# 3   1050613   2018-01-01         ES        50.0      M   22        N  119776.0
# 4   1050614   2018-01-01         ES        50.0      H   23        N   96796.0
# 5   1050615   2018-01-01         ES        45.0      M   23        N   22220.0
# 6   1050616   2018-01-01         ES        24.0      M   23        N  295590.0
# 7   1050617   2018-01-01         ES        50.0      M   23        N  113317.0
# 8   1050619   2018-01-01         ES        20.0      M   24        N   53029.0
# 9   1050620   2018-01-01         ES        10.0      M   23        N  113195.0
# 10  1050621   2018-01-01         ES        50.0      H   23        N   72576.0
# 11  1050622   2018-01-01         ES        17.0      M   23        N  108230.0
# 12  1050623   2018-01-01         ES        49.0      M   23        N  113539.0
# 13  1050624   2018-01-01         ES        50.0      M   65        N   61605.0
# 14  1050625   2018-01-01         ES        49.0      H   23        N   73417.0
# 15  1050626   2018-01-01         ES         8.0      H   23        N  124622.0
# 16  1050610   2018-01-01         ES        37.0      H   24        N   68318.0
# 17  1050627   2018-01-01         ES        13.0      M   23        N   65608.0
# 18  1050609   2018-01-01         ES        13.0      M   22        N   73432.0
# 19  1050605   2018-01-01         ES        45.0      H   23        N   65586.0

# %%
mostrar_informacion_dataframe(customer_sociodemographics1)
# Out:
# Información de: customer_sociodemographics1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   pk_cid        object
#  1   pk_partition  datetime64[ns]
#  2   country_id    object
#  3   region_code   object
#  4   gender        object
#  5   age           int8
#  6   deceased      object
#  7   salary        float64
# dtypes: datetime64[ns](1), float64(1), int8(1), object(5)
# memory usage: 324.1+ MB
#
# Recuento de valores únicos en la columna:
# 1375586    17
# 1328781    17
# 1328783    17
# 1328784    17
# 1328786    17
#            ..
# 1521045     1
# 1545224     1
# 1470941     1
# 1521049     1
# 1550586     1
# Name: pk_cid, Length: 456373, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2019-05-01    442995
# 2019-04-01    439627
# 2019-03-01    436183
# 2019-02-01    431727
# 2019-01-01    426875
# 2018-12-01    422481
# 2018-11-01    416387
# 2018-10-01    402300
# 2018-09-01    375323
# 2018-08-01    352922
# 2018-07-01    339339
# 2018-06-01    252104
# 2018-05-01    249926
# 2018-04-01    247463
# 2018-03-01    245258
# 2018-02-01    242521
# 2018-01-01    239493
# Name: pk_partition, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# ES    5960672
# GB        441
# FR        225
# DE        199
# US        195
# CH        194
# BR         87
# BE         81
# VE         79
# IE         68
# MX         58
# AT         51
# AR         51
# PL         49
# IT         45
# MA         34
# CL         30
# CN         28
# CA         22
# LU         17
# ET         17
# QA         17
# CI         17
# SA         17
# CM         17
# SN         17
# MR         17
# NO         17
# RU         17
# CO         17
# GA         17
# GT         17
# DO         17
# SE         16
# DJ         11
# PT         11
# JM         11
# RO          9
# HU          8
# DZ          7
# PE          4
# Name: country_id, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 28.0    1185757
# 8.0      600362
# 46.0     358142
# 30.0     296856
# 41.0     290447
# 15.0     254891
# 29.0     187911
# 36.0     175850
# 3.0      171358
# 11.0     160894
# 33.0     134562
# 50.0     132983
# 6.0      122587
# 35.0     121982
# 47.0     116948
# 18.0     102789
# 45.0     102328
# 37.0      92538
# 10.0      83283
# 14.0      75405
# 2.0       72071
# 21.0      72037
# 13.0      70092
# 39.0      69589
# 12.0      68709
# 7.0       62436
# 32.0      54639
# 27.0      52783
# 43.0      51782
# 17.0      50749
# 9.0       47746
# 25.0      46887
# 16.0      36094
# 24.0      35426
# 48.0      35256
# 26.0      34790
# 4.0       32680
# 31.0      31241
# 49.0      30965
# 23.0      30955
# 38.0      29001
# 34.0      27545
# 19.0      26762
# 40.0      21658
# 5.0       21300
# 22.0      21112
# 20.0      18833
# 1.0       12999
# 44.0      12616
# 42.0       8500
# 51.0       2896
# 52.0       2638
# 0.0        2264
# Name: region_code, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# M          3087502
# H          2875397
# no_data         25
# Name: gender, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 22     727134
# 23     702127
# 21     667762
# 20     413568
# 24     408569
#         ...
# 101        91
# 102        65
# 103        25
# 104        12
# 105         8
# Name: age, Length: 104, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# N    5961849
# S       1075
# Name: deceased, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 126179.0    268197
# 124622.0    112975
# 65932.0      88972
# 68038.0      82734
# 94054.0      76831
#              ...
# 192297.0         1
# 178581.0         1
# 162628.0         1
# 19559.0          1
# 153535.0         1
# Name: salary, Length: 142258, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0

# %% [markdown]
# ## 2.4 sales

# %% [markdown]
# ### Analizamos *sales*

# %%
mostrar_informacion_dataframe(sales1)
# Out:
# Información de: sales1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240773 entries, 0 to 240772
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   pk_sale     240773 non-null  int64
#  1   cid         240773 non-null  int64
#  2   month_sale  240773 non-null  object
#  3   product_ID  240773 non-null  int64
#  4   net_margin  240773 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 9.2+ MB
#
# Recuento de valores únicos en la columna:
# 6666      1
# 167186    1
# 167174    1
# 167175    1
# 167176    1
#          ..
# 86928     1
# 86929     1
# 86930     1
# 86931     1
# 247438    1
# Name: pk_sale, Length: 240773, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 1387215    10
# 1436512     9
# 1380507     9
# 1402957     9
# 1402199     9
#            ..
# 1409414     1
# 1409413     1
# 1409412     1
# 1409410     1
# 1553571     1
# Name: cid, Length: 152754, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2018-10-01    27693
# 2018-09-01    24488
# 2018-08-01    21054
# 2018-07-01    20602
# 2018-11-01    19155
# 2018-02-01    15182
# 2018-12-01    15015
# 2019-01-01    11872
# 2018-03-01    11668
# 2018-06-01    11558
# 2019-03-01    11506
# 2019-02-01    11360
# 2019-05-01    10211
# 2018-04-01     9962
# 2019-04-01     9889
# 2018-05-01     9558
# Name: month_sale, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 4657    117435
# 3819     38840
# 1364     19369
# 2234     18750
# 2235     18110
# 8871     12323
# 2312      5206
# 2335      4441
# 2336      4227
# 2673      1157
# 1119       880
# 9001        25
# 4033        10
# Name: product_ID, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 63.1       890
# 64.8       854
# 63.9       851
# 64.1       848
# 62.7       841
#           ...
# 4917.3       1
# 5698.9       1
# 5708.1       1
# 11009.5      1
# 34.5         1
# Name: net_margin, Length: 25451, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0

# %% [markdown]
# Análisis:
#
#
# *   pk_sale:ok, 100% valores únicos
# *   cid: cambiar a object
# *   month_sale: cambiar a datetime
# *   product_ID: cambiar a object
# *   net_margin: ok

# %% [markdown]
# #### cid

# %%
sales1["cid"] = sales1["cid"].astype(str)

# %% [markdown]
# ####month_sale

# %%
sales1["month_sale"] = pd.to_datetime(sales1["month_sale"], format= "%Y-%m-%d")

# %% [markdown]
# ####product_ID

# %%
sales1["product_ID"] = sales1["product_ID"].astype(str)

# %%
mostrar_informacion_dataframe(sales1)
# Out:
# Información de: sales1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240773 entries, 0 to 240772
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   pk_sale     240773 non-null  int64
#  1   cid         240773 non-null  object
#  2   month_sale  240773 non-null  datetime64[ns]
#  3   product_ID  240773 non-null  object
#  4   net_margin  240773 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 9.2+ MB
#
# Recuento de valores únicos en la columna:
# 6666      1
# 167186    1
# 167174    1
# 167175    1
# 167176    1
#          ..
# 86928     1
# 86929     1
# 86930     1
# 86931     1
# 247438    1
# Name: pk_sale, Length: 240773, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 1387215    10
# 1436512     9
# 1380507     9
# 1402957     9
# 1402199     9
#            ..
# 1409414     1
# 1409413     1
# 1409412     1
# 1409410     1
# 1553571     1
# Name: cid, Length: 152754, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 2018-10-01    27693
# 2018-09-01    24488
# 2018-08-01    21054
# 2018-07-01    20602
# 2018-11-01    19155
# 2018-02-01    15182
# 2018-12-01    15015
# 2019-01-01    11872
# 2018-03-01    11668
# 2018-06-01    11558
# 2019-03-01    11506
# 2019-02-01    11360
# 2019-05-01    10211
# 2018-04-01     9962
# 2019-04-01     9889
# 2018-05-01     9558
# Name: month_sale, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 4657    117435
# 3819     38840
# 1364     19369
# 2234     18750
# 2235     18110
# 8871     12323
# 2312      5206
# 2335      4441
# 2336      4227
# 2673      1157
# 1119       880
# 9001        25
# 4033        10
# Name: product_ID, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# 63.1       890
# 64.8       854
# 63.9       851
# 64.1       848
# 62.7       841
#           ...
# 4917.3       1
# 5698.9       1
# 5708.1       1
# 11009.5      1
# 34.5         1
# Name: net_margin, Length: 25451, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0

# %% [markdown]
# ## 2.5 product_description

# %% [markdown]
# ### 1.6.1 Analizamos *product_description*

# %%
mostrar_informacion_dataframe(product_description1)
# Out:
# Información de: product_description1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pk_product_ID   13 non-null     int64
#  1   product_desc    13 non-null     object
#  2   family_product  13 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 440.0+ bytes
#
# Recuento de valores únicos en la columna:
# 4657    1
# 3819    1
# 1364    1
# 2234    1
# 2235    1
# 8871    1
# 2312    1
# 2335    1
# 2336    1
# 2673    1
# 1119    1
# 9001    1
# 4033    1
# Name: pk_product_ID, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# em_acount             1
# debit_card            1
# pension_plan          1
# payroll               1
# payroll_account       1
# emc_account           1
# credit_card           1
# short_term_deposit    1
# long_term_deposit     1
# securities            1
# funds                 1
# loans                 1
# mortgage              1
# Name: product_desc, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0
#
#
#
# Recuento de valores únicos en la columna:
# account         4
# investment      4
# payment_card    2
# loan            2
# pension_plan    1
# Name: family_product, dtype: int64
#
#
#
# Recuento de valores nulos en la columna:
# 0

# %% [markdown]
# Analizamos:
#
# *   pk_product_ID: cambiar a object

# %%
product_description1["pk_product_ID"] = product_description1["pk_product_ID"].astype(str)

# %%
product_description1
# Out:
#    pk_product_ID        product_desc family_product
# 0           4657           em_acount        account
# 1           3819          debit_card   payment_card
# 2           1364        pension_plan   pension_plan
# 3           2234             payroll        account
# 4           2235     payroll_account        account
# 5           8871         emc_account        account
# 6           2312         credit_card   payment_card
# 7           2335  short_term_deposit     investment
# 8           2336   long_term_deposit     investment
# 9           2673          securities     investment
# 10          1119               funds     investment
# 11          9001               loans           loan
# 12          4033            mortgage           loan

# %% [markdown]
# ##Relación pk_cid y pk_partition

# %%
#def filtrar_dataframe(df):
#    df_filtrado = df.groupby('pk_cid').agg({'pk_partition': 'max'}).reset_index()
#    df_filtrado = df_filtrado.merge(df, on=['pk_cid', 'pk_partition'], how='left')
#    return df_filtrado

# %%
# df_filtrado = filtrar_dataframe(customer_commercial_activity1)

# %%
#df_filtrado

# %%
#df_filtrado.name = "df_filtrado"

# %%
#mostrar_informacion_dataframe(df_filtrado)

# %%
#df_filtrado["pk_cid"].value_counts()

# %% [markdown]
# # **3. Creamos el modelo relacional de datos**

# %%
#df_filtrado = customer_commercial_activity1.merge(customer_commercial_activity1, on=['pk_cid', 'pk_partition'], how='left')

# %%
#customer_commercial_activity1.head()

# %%
#customer_products1.head()

# %%
# Crear modelo relacional de datos:   Vamos a hacer join sobre: customer_commercial_activity1, customer_products1 y customer_sociodemographics1
merged_data = customer_commercial_activity1.merge(customer_products1, on=['pk_cid', 'pk_partition'], how='left')

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5962924 entries, 0 to 5962923
# Data columns (total 21 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   pk_cid              object
#  1   pk_partition        datetime64[ns]
#  2   entry_date          datetime64[ns]
#  3   entry_channel       object
#  4   active_customer     int8
#  5   segment             object
#  6   short_term_deposit  int8
#  7   loans               int8
#  8   mortgage            int8
#  9   funds               int8
#  10  securities          int8
#  11  long_term_deposit   int8
#  12  em_account_pp       int8
#  13  credit_card         int8
#  14  payroll             int8
#  15  pension_plan        int8
#  16  payroll_account     int8
#  17  emc_account         int8
#  18  debit_card          int8
#  19  em_account_p        int8
#  20  em_acount           int8
# dtypes: datetime64[ns](2), int8(16), object(3)
# memory usage: 363.9+ MB

# %%
merged_data.isnull().sum()
# Out:
# pk_cid                0
# pk_partition          0
# entry_date            0
# entry_channel         0
# active_customer       0
# segment               0
# short_term_deposit    0
# loans                 0
# mortgage              0
# funds                 0
# securities            0
# long_term_deposit     0
# em_account_pp         0
# credit_card           0
# payroll               0
# pension_plan          0
# payroll_account       0
# emc_account           0
# debit_card            0
# em_account_p          0
# em_acount             0
# dtype: int64

# %%
merged_data[merged_data['loans'].isnull()]
# Out:
# Empty DataFrame
# Columns: [pk_cid, pk_partition, entry_date, entry_channel, active_customer, segment, short_term_deposit, loans, mortgage, funds, securities, long_term_deposit, em_account_pp, credit_card, payroll, pension_plan, payroll_account, emc_account, debit_card, em_account_p, em_acount]
# Index: []
#
# [0 rows x 21 columns]

# %%
merged_data = merged_data.merge(customer_sociodemographics1, on=['pk_cid', 'pk_partition'], how='left')

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5962924 entries, 0 to 5962923
# Data columns (total 27 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   pk_cid              object
#  1   pk_partition        datetime64[ns]
#  2   entry_date          datetime64[ns]
#  3   entry_channel       object
#  4   active_customer     int8
#  5   segment             object
#  6   short_term_deposit  int8
#  7   loans               int8
#  8   mortgage            int8
#  9   funds               int8
#  10  securities          int8
#  11  long_term_deposit   int8
#  12  em_account_pp       int8
#  13  credit_card         int8
#  14  payroll             int8
#  15  pension_plan        int8
#  16  payroll_account     int8
#  17  emc_account         int8
#  18  debit_card          int8
#  19  em_account_p        int8
#  20  em_acount           int8
#  21  country_id          object
#  22  region_code         object
#  23  gender              object
#  24  age                 int8
#  25  deceased            object
#  26  salary              float64
# dtypes: datetime64[ns](2), float64(1), int8(17), object(7)
# memory usage: 597.1+ MB

# %%
merged_data["pk_cid"].nunique()
# Out:
# 456373

# %%
product_description1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pk_product_ID   13 non-null     object
#  1   product_desc    13 non-null     object
#  2   family_product  13 non-null     object
# dtypes: object(3)
# memory usage: 440.0+ bytes

# %%
#El siguiente merge será entre: sales1 y product_description1
merged_data_2 = sales1.merge(product_description1, left_on='product_ID', right_on='pk_product_ID', how='left')

# %%
merged_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240773 entries, 0 to 240772
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pk_sale         240773 non-null  int64
#  1   cid             240773 non-null  object
#  2   month_sale      240773 non-null  datetime64[ns]
#  3   product_ID      240773 non-null  object
#  4   net_margin      240773 non-null  float64
#  5   pk_product_ID   240773 non-null  object
#  6   product_desc    240773 non-null  object
#  7   family_product  240773 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 16.5+ MB

# %%
merged_data_2.isnull().sum()
# Out:
# pk_sale           0
# cid               0
# month_sale        0
# product_ID        0
# net_margin        0
# pk_product_ID     0
# product_desc      0
# family_product    0
# dtype: int64

# %%
del(merged_data_2['product_ID'])

# %%
# merged_data = merged_data.merge(merged_data_2, left_on=['pk_cid'], right_on=['cid'], how='inner')

# %%
#merged_data = merged_data_2.merge(merged_data, left_on=['cid'], right_on=['pk_cid'], how='inner') # este es el merge correcto para el powerbi

# %%
merged_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240773 entries, 0 to 240772
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pk_sale         240773 non-null  int64
#  1   cid             240773 non-null  object
#  2   month_sale      240773 non-null  datetime64[ns]
#  3   net_margin      240773 non-null  float64
#  4   pk_product_ID   240773 non-null  object
#  5   product_desc    240773 non-null  object
#  6   family_product  240773 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 14.7+ MB

# %%
merged_data.head(3).T
# Out:
#                                       0                    1  \
# pk_cid                          1375586              1050611
# pk_partition        2018-01-01 00:00:00  2018-01-01 00:00:00
# entry_date          2018-01-01 00:00:00  2015-08-01 00:00:00
# entry_channel                       KHL                  KHE
# active_customer                       1                    0
# segment               02 - PARTICULARES   03 - UNIVERSITARIO
# short_term_deposit                    0                    0
# loans                                 0                    0
# mortgage                              0                    0
# funds                                 0                    0
# securities                            0                    0
# long_term_deposit                     0                    0
# em_account_pp                         0                    0
# credit_card                           0                    0
# payroll                               0                    0
# pension_plan                          0                    0
# payroll_account                       0                    0
# emc_account                           0                    0
# debit_card                            0                    0
# em_account_p                          0                    0
# em_acount                             1                    1
# country_id                           ES                   ES
# region_code                        29.0                 13.0
# gender                                M                    H
# age                                  35                   23
# deceased                              N                    N
# salary                          87218.0              35549.0
#
#                                       2
# pk_cid                          1050612
# pk_partition        2018-01-01 00:00:00
# entry_date          2015-08-01 00:00:00
# entry_channel                       KHE
# active_customer                       0
# segment              03 - UNIVERSITARIO
# short_term_deposit                    0
# loans                                 0
# mortgage                              0
# funds                                 0
# securities                            0
# long_term_deposit                     0
# em_account_pp                         0
# credit_card                           0
# payroll                               0
# pension_plan                          0
# payroll_account                       0
# emc_account                           0
# debit_card                            0
# em_account_p                          0
# em_acount                             1
# country_id                           ES
# region_code                        13.0
# gender                                H
# age                                  23
# deceased                              N
# salary                         122179.0

# %%
merged_data_2.head(3).T
# Out:
#                                   0                    1                    2
# pk_sale                        6666                 6667                 6668
# cid                           33620                35063                37299
# month_sale      2018-05-01 00:00:00  2018-06-01 00:00:00  2018-02-01 00:00:00
# net_margin                    952.9               1625.2               1279.7
# pk_product_ID                  2335                 2335                 2335
# product_desc     short_term_deposit   short_term_deposit   short_term_deposit
# family_product           investment           investment           investment

# %%
merged_data_2[merged_data_2["net_margin"]==0]
# Out:
# Empty DataFrame
# Columns: [pk_sale, cid, month_sale, net_margin, pk_product_ID, product_desc, family_product]
# Index: []

# %% [markdown]
# # **4. Creamos nuevas variables**

# %%
#Creamos la variable, suma de productos para saber cuantos productos tiene cada cliente.

# %%
columnas_productos=['short_term_deposit',
 'loans',
 'mortgage',
 'funds',
 'securities',
 'long_term_deposit',
 'em_account_pp',
 'credit_card',
 'payroll',
 'pension_plan',
 'payroll_account',
 'emc_account',
 'debit_card',
 'em_account_p',
 'em_acount']

# %%
merged_data["Suma_productos_activos"]=merged_data[columnas_productos].sum(axis=1)

# %%
merged_data.tail(20)
# Out:
#           pk_cid pk_partition entry_date entry_channel  active_customer  \
# 5962904  1166780   2019-05-01 2016-08-01           KHE                0
# 5962905  1166779   2019-05-01 2016-08-01           KHE                1
# 5962906  1166778   2019-05-01 2016-08-01           KHE                1
# 5962907  1166777   2019-05-01 2016-08-01           KHE                0
# 5962908  1166776   2019-05-01 2016-08-01           KHE                0
# 5962909  1166775   2019-05-01 2016-08-01           KHE                1
# 5962910  1166774   2019-05-01 2016-08-01           KHE                0
# 5962911  1166773   2019-05-01 2016-08-01           KHE                0
# 5962912  1166772   2019-05-01 2016-08-01           KHE                0
# 5962913  1166771   2019-05-01 2016-08-01           KHE                0
# 5962914  1166770   2019-05-01 2016-08-01           KHE                0
# 5962915  1166769   2019-05-01 2016-08-01           KHE                0
# 5962916  1166768   2019-05-01 2016-08-01           KHE                0
# 5962917  1166767   2019-05-01 2016-08-01           KHE                0
# 5962918  1166766   2019-05-01 2016-08-01           KHE                0
# 5962919  1166765   2019-05-01 2016-08-01           KHE                0
# 5962920  1166764   2019-05-01 2016-08-01           KHE                0
# 5962921  1166763   2019-05-01 2016-08-01           KHE                1
# 5962922  1166789   2019-05-01 2016-08-01           KHE                0
# 5962923  1550586   2019-05-01 2019-05-01       No_data                1
#
#                     segment  short_term_deposit  loans  mortgage  funds  ...  \
# 5962904  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962905  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962906  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962907  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962908  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962909  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962910  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962911  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962912  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962913  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962914  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962915  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962916  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962917  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962918  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962919  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962920  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962921   02 - PARTICULARES                   0      0         0      0  ...
# 5962922  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962923           no_indica                   0      0         0      0  ...
#
#          debit_card  em_account_p  em_acount  country_id  region_code  gender  \
# 5962904           0             0          1          ES         50.0       M
# 5962905           0             0          1          ES         50.0       H
# 5962906           0             0          1          ES         50.0       H
# 5962907           0             0          1          ES         50.0       H
# 5962908           0             0          1          ES         50.0       M
# 5962909           0             0          1          ES         50.0       H
# 5962910           0             0          1          ES         50.0       M
# 5962911           0             0          0          ES         44.0       M
# 5962912           0             0          1          ES         50.0       H
# 5962913           0             0          1          ES         50.0       M
# 5962914           0             0          1          ES         50.0       M
# 5962915           0             0          1          ES         50.0       M
# 5962916           0             0          1          ES         50.0       H
# 5962917           0             0          1          ES         50.0       H
# 5962918           0             0          1          ES         50.0       H
# 5962919           0             0          1          ES         50.0       H
# 5962920           0             0          1          ES         26.0       H
# 5962921           0             0          1          ES         50.0       M
# 5962922           0             0          1          ES         50.0       M
# 5962923           0             0          1          ES         28.0       M
#
#          age  deceased    salary  Suma_productos_activos
# 5962904   28         N   58274.0                       1
# 5962905   23         N   57303.0                       1
# 5962906   23         N   96796.0                       1
# 5962907   23         N  157610.0                       1
# 5962908   23         N   96796.0                       1
# 5962909   23         N   77785.0                       1
# 5962910   22         N  160866.0                       1
# 5962911   23         N   83822.0                       0
# 5962912   23         N  100154.0                       1
# 5962913   23         N   96796.0                       1
# 5962914   23         N   85873.0                       1
# 5962915   26         N   47093.0                       1
# 5962916   23         N   65850.0                       1
# 5962917   25         N   73135.0                       1
# 5962918   25         N   50945.0                       1
# 5962919   22         N   43912.0                       1
# 5962920   23         N   23335.0                       1
# 5962921   47         N   96796.0                       1
# 5962922   22         N  199593.0                       1
# 5962923   37         N  126179.0                       1
#
# [20 rows x 28 columns]

# %%
merged_data["Suma_productos_activos"].value_counts()
# Out:
# 1    3995714
# 0    1121507
# 2     528593
# 3     150269
# 4     105720
# 5      42890
# 6      14809
# 7       2799
# 8        573
# 9         50
# Name: Suma_productos_activos, dtype: int64

# %% [markdown]
# revisamos que 1121507 no tienen ningún producto activo

# %%
merged_data[merged_data["Suma_productos_activos"]==0]
# Out:
#           pk_cid pk_partition entry_date entry_channel  active_customer  \
# 43       1050680   2018-01-01 2015-08-01           KFC                0
# 46       1050693   2018-01-01 2015-08-01           KFC                0
# 388      1050141   2018-01-01 2015-08-01           KHD                0
# 532      1050389   2018-01-01 2015-08-01           KHE                0
# 543      1050337   2018-01-01 2015-08-01           KHE                1
# ...          ...          ...        ...           ...              ...
# 5962890  1166735   2019-05-01 2016-08-01           KHE                0
# 5962892  1166733   2019-05-01 2016-08-01           KHE                0
# 5962893  1166744   2019-05-01 2016-08-01           KHE                0
# 5962896  1166762   2019-05-01 2016-08-01           KHE                0
# 5962911  1166773   2019-05-01 2016-08-01           KHE                0
#
#                     segment  short_term_deposit  loans  mortgage  funds  ...  \
# 43        02 - PARTICULARES                   0      0         0      0  ...
# 46        02 - PARTICULARES                   0      0         0      0  ...
# 388      03 - UNIVERSITARIO                   0      0         0      0  ...
# 532       02 - PARTICULARES                   0      0         0      0  ...
# 543      03 - UNIVERSITARIO                   0      0         0      0  ...
# ...                     ...                 ...    ...       ...    ...  ...
# 5962890  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962892  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962893  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962896  03 - UNIVERSITARIO                   0      0         0      0  ...
# 5962911  03 - UNIVERSITARIO                   0      0         0      0  ...
#
#          debit_card  em_account_p  em_acount  country_id  region_code  gender  \
# 43                0             0          0          ES          8.0       H
# 46                0             0          0          ES          8.0       H
# 388               0             0          0          ES         15.0       H
# 532               0             0          0          ES         15.0       H
# 543               0             0          0          ES         45.0       M
# ...             ...           ...        ...         ...          ...     ...
# 5962890           0             0          0          ES         41.0       M
# 5962892           0             0          0          ES          4.0       H
# 5962893           0             0          0          ES          8.0       M
# 5962896           0             0          0          ES         46.0       H
# 5962911           0             0          0          ES         44.0       M
#
#          age  deceased    salary  Suma_productos_activos
# 43        53         N  133092.0                       0
# 46        37         N  104035.0                       0
# 388       22         N   52521.0                       0
# 532       35         N  160539.0                       0
# 543       31         N   24625.0                       0
# ...      ...       ...       ...                     ...
# 5962890   22         N  120470.0                       0
# 5962892   22         N  128305.0                       0
# 5962893   22         N  128384.0                       0
# 5962896   22         N   99713.0                       0
# 5962911   23         N   83822.0                       0
#
# [1121507 rows x 28 columns]

# %%
# Días como cliente

merged_data["d_cliente"] = (merged_data['pk_partition'] - merged_data['entry_date']).dt.days

# %%
merged_data.head(3).T
# Out:
#                                           0                    1  \
# pk_cid                              1375586              1050611
# pk_partition            2018-01-01 00:00:00  2018-01-01 00:00:00
# entry_date              2018-01-01 00:00:00  2015-08-01 00:00:00
# entry_channel                           KHL                  KHE
# active_customer                           1                    0
# segment                   02 - PARTICULARES   03 - UNIVERSITARIO
# short_term_deposit                        0                    0
# loans                                     0                    0
# mortgage                                  0                    0
# funds                                     0                    0
# securities                                0                    0
# long_term_deposit                         0                    0
# em_account_pp                             0                    0
# credit_card                               0                    0
# payroll                                   0                    0
# pension_plan                              0                    0
# payroll_account                           0                    0
# emc_account                               0                    0
# debit_card                                0                    0
# em_account_p                              0                    0
# em_acount                                 1                    1
# country_id                               ES                   ES
# region_code                            29.0                 13.0
# gender                                    M                    H
# age                                      35                   23
# deceased                                  N                    N
# salary                              87218.0              35549.0
# Suma_productos_activos                    1                    1
# d_cliente                                 0                  884
#
#                                           2
# pk_cid                              1050612
# pk_partition            2018-01-01 00:00:00
# entry_date              2015-08-01 00:00:00
# entry_channel                           KHE
# active_customer                           0
# segment                  03 - UNIVERSITARIO
# short_term_deposit                        0
# loans                                     0
# mortgage                                  0
# funds                                     0
# securities                                0
# long_term_deposit                         0
# em_account_pp                             0
# credit_card                               0
# payroll                                   0
# pension_plan                              0
# payroll_account                           0
# emc_account                               0
# debit_card                                0
# em_account_p                              0
# em_acount                                 1
# country_id                               ES
# region_code                            13.0
# gender                                    H
# age                                      23
# deceased                                  N
# salary                             122179.0
# Suma_productos_activos                    1
# d_cliente                               884

# %%
# Ahora la idea es conocer cuales son los productos con los que los clientes empiezan a trabajar con Easy Bank
#lista_prod_venta1 = merged_data.groupby('product_desc')['días_para_compra'].mean()
#lista_prod_venta1.sort_values(ascending=True)

#esto lo agrego al DDSS??

# %%
#Analizamos el net_margin de cada producto

resumen_net_margin = merged_data_2.groupby(['month_sale','product_desc'])['net_margin'].agg(
    mean_net_margin= 'mean',
    max_net_margin= 'max',
    min_net_margin= 'min',
    median_net_margin= 'median'
)
resumen_net_margin
# Out:
#                               mean_net_margin  max_net_margin  min_net_margin  \
# month_sale product_desc
# 2018-02-01 credit_card              59.811961            82.3            46.1
#            debit_card               60.027940            79.0            42.9
#            em_acount                70.002502           103.9            31.4
#            emc_account              70.057249           108.7            39.7
#            funds                  1522.801031          2967.8           713.9
# ...                                       ...             ...             ...
# 2019-05-01 long_term_deposit      1992.950000          2271.6          1714.3
#            payroll                  69.576027           100.4            27.7
#            payroll_account          69.002133            96.6            33.9
#            pension_plan           6071.558669         17133.2          1793.2
#            securities             1375.783333          2107.4           844.0
#
#                               median_net_margin
# month_sale product_desc
# 2018-02-01 credit_card                    59.85
#            debit_card                     60.00
#            em_acount                      70.10
#            emc_account                    69.70
#            funds                        1509.00
# ...                                         ...
# 2019-05-01 long_term_deposit            1992.95
#            payroll                        69.75
#            payroll_account                68.90
#            pension_plan                 5689.10
#            securities                   1256.35
#
# [190 rows x 4 columns]

# %%
#cuantos clientes tienen em_account_pp y em_account_p

# %%
merged_data['em_account_pp'].sum()
# Out:
# 0

# %%
merged_data['em_account_p'].sum()
# Out:
# 34

# %% [markdown]
# Decidimos borrar ambas condiciones también para estar alineados con product_desc

# %%
del(merged_data['em_account_pp'])

# %%
del(merged_data['em_account_p'])

# %%
#altas de cada producto

# %%
TOTAL_VENTAS = merged_data_2.pivot_table(index='month_sale', columns='product_desc', aggfunc='size', fill_value=0)
TOTAL_VENTAS
# Out:
# product_desc  credit_card  debit_card  em_acount  emc_account  funds  loans  \
# month_sale
# 2018-02-01            510        3708       4156          807     97      0
# 2018-03-01            551        2691       3521          786    118      4
# 2018-04-01            400        2122       3004          705    124      3
# 2018-05-01            373        1804       3065          712     81      3
# 2018-06-01            406        1834       4711          561     51      0
# 2018-07-01            390        1942      12439          403     52      1
# 2018-08-01            331        1943      14129          339     58      2
# 2018-09-01            281        2514      17513          474     34      2
# 2018-10-01            287        3426      18988          447     37      2
# 2018-11-01            259        2908      10517          799     50      0
# 2018-12-01            221        2483       6223          767     56      1
# 2019-01-01            215        2160       5137         1017     34      1
# 2019-02-01            248        2537       3952         1066     25      1
# 2019-03-01            249        2590       4210          878     20      3
# 2019-04-01            236        2129       3012         1113     26      2
# 2019-05-01            249        2049       2858         1449     17      0
#
# product_desc  long_term_deposit  mortgage  payroll  payroll_account  \
# month_sale
# 2018-02-01                  225         0     1966              974
# 2018-03-01                  249         2     1080              888
# 2018-04-01                  230         1      987              909
# 2018-05-01                  340         1      918              916
# 2018-06-01                  371         1     1091              945
# 2018-07-01                  417         1     1550             1295
# 2018-08-01                  312         0     1073             1267
# 2018-09-01                  450         0      904              815
# 2018-10-01                  453         0     1184             1077
# 2018-11-01                  338         0     1270             1590
# 2018-12-01                  410         0     1366             1955
# 2019-01-01                  178         1      880             1055
# 2019-02-01                  192         0     1078             1046
# 2019-03-01                   50         0     1143             1120
# 2019-04-01                   10         3     1092             1086
# 2019-05-01                    2         0     1168             1172
#
# product_desc  pension_plan  securities  short_term_deposit
# month_sale
# 2018-02-01            2006          68                 665
# 2018-03-01            1088          39                 651
# 2018-04-01            1025          33                 419
# 2018-05-01             927          38                 380
# 2018-06-01            1113          34                 440
# 2018-07-01            1621          41                 450
# 2018-08-01            1097          73                 430
# 2018-09-01             940          65                 496
# 2018-10-01            1208         173                 411
# 2018-11-01            1296          35                  93
# 2018-12-01            1449          78                   6
# 2019-01-01             946         248                   0
# 2019-02-01            1102         113                   0
# 2019-03-01            1186          57                   0
# 2019-04-01            1148          32                   0
# 2019-05-01            1217          30                   0

# %%
TOTAL_VENTAS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16 entries, 2018-02-01 to 2019-05-01
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   credit_card         16 non-null     int64
#  1   debit_card          16 non-null     int64
#  2   em_acount           16 non-null     int64
#  3   emc_account         16 non-null     int64
#  4   funds               16 non-null     int64
#  5   loans               16 non-null     int64
#  6   long_term_deposit   16 non-null     int64
#  7   mortgage            16 non-null     int64
#  8   payroll             16 non-null     int64
#  9   payroll_account     16 non-null     int64
#  10  pension_plan        16 non-null     int64
#  11  securities          16 non-null     int64
#  12  short_term_deposit  16 non-null     int64
# dtypes: int64(13)
# memory usage: 1.8 KB

# %%
TOTAL_VENTAS = TOTAL_VENTAS.rename(columns={
    'credit_card': 'credit_card_venta',
    'debit_card': 'debit_card_venta',
    'em_acount': 'em_acount_venta',
    'emc_account': 'emc_account_venta',
    'funds': 'funds_venta',
    'loans': 'loans_venta',
    'long_term_deposit': 'long_term_deposit_venta',
    'mortgage': 'mortgage_venta',
    'payroll': 'payroll_venta',
    'payroll_account': 'payroll_account_venta',
    'pension_plan': 'pension_plan_venta',
    'securities': 'securities_venta',
    'short_term_deposit': 'short_term_deposit_venta'
})

# %%
TOTAL_VENTAS = TOTAL_VENTAS.rename_axis('pk_partition')

# %%
TOTAL_VENTAS.head(10)
# Out:
# product_desc  credit_card_venta  debit_card_venta  em_acount_venta  \
# pk_partition
# 2018-02-01                  510              3708             4156
# 2018-03-01                  551              2691             3521
# 2018-04-01                  400              2122             3004
# 2018-05-01                  373              1804             3065
# 2018-06-01                  406              1834             4711
# 2018-07-01                  390              1942            12439
# 2018-08-01                  331              1943            14129
# 2018-09-01                  281              2514            17513
# 2018-10-01                  287              3426            18988
# 2018-11-01                  259              2908            10517
#
# product_desc  emc_account_venta  funds_venta  loans_venta  \
# pk_partition
# 2018-02-01                  807           97            0
# 2018-03-01                  786          118            4
# 2018-04-01                  705          124            3
# 2018-05-01                  712           81            3
# 2018-06-01                  561           51            0
# 2018-07-01                  403           52            1
# 2018-08-01                  339           58            2
# 2018-09-01                  474           34            2
# 2018-10-01                  447           37            2
# 2018-11-01                  799           50            0
#
# product_desc  long_term_deposit_venta  mortgage_venta  payroll_venta  \
# pk_partition
# 2018-02-01                        225               0           1966
# 2018-03-01                        249               2           1080
# 2018-04-01                        230               1            987
# 2018-05-01                        340               1            918
# 2018-06-01                        371               1           1091
# 2018-07-01                        417               1           1550
# 2018-08-01                        312               0           1073
# 2018-09-01                        450               0            904
# 2018-10-01                        453               0           1184
# 2018-11-01                        338               0           1270
#
# product_desc  payroll_account_venta  pension_plan_venta  securities_venta  \
# pk_partition
# 2018-02-01                      974                2006                68
# 2018-03-01                      888                1088                39
# 2018-04-01                      909                1025                33
# 2018-05-01                      916                 927                38
# 2018-06-01                      945                1113                34
# 2018-07-01                     1295                1621                41
# 2018-08-01                     1267                1097                73
# 2018-09-01                      815                 940                65
# 2018-10-01                     1077                1208               173
# 2018-11-01                     1590                1296                35
#
# product_desc  short_term_deposit_venta
# pk_partition
# 2018-02-01                         665
# 2018-03-01                         651
# 2018-04-01                         419
# 2018-05-01                         380
# 2018-06-01                         440
# 2018-07-01                         450
# 2018-08-01                         430
# 2018-09-01                         496
# 2018-10-01                         411
# 2018-11-01                          93

# %%
TOTAL_STOCK = merged_data.groupby(['pk_partition']).agg(
    {
        'credit_card':np.sum,
        'debit_card':np.sum,
        'em_acount':np.sum,
        'emc_account':np.sum,
        'funds':np.sum,
        'loans':np.sum,
        'long_term_deposit':np.sum,
        'mortgage':np.sum,
        'payroll':np.sum,
        'payroll_account':np.sum,
        'pension_plan':np.sum,
        'securities':np.sum,
        'short_term_deposit':np.sum
    }
)
TOTAL_STOCK
# Out:
#               credit_card  debit_card  em_acount  emc_account  funds  loans  \
# pk_partition
# 2018-01-01           3325       24696     215293        15320    786     19
# 2018-02-01           3282       25448     217098        15827    872     19
# 2018-03-01           3511       27046     218683        16428    969     23
# 2018-04-01           3725       27764     219816        16947   1084     24
# 2018-05-01           3797       27911     221291        17569   1145     27
# 2018-06-01           4002       28828     224328        17950   1159     27
# 2018-07-01           4137       29578     234324        18185   1172     28
# 2018-08-01           4206       29205     245980        18333   1219     29
# 2018-09-01           4289       31684     261210        18618   1237     31
# 2018-10-01           4385       34372     277707        18844   1249     33
# 2018-11-01           4512       35466     284900        19494   1282     32
# 2018-12-01           4536       37430     288928        20043   1322     30
# 2019-01-01           4493       37350     291786        20921   1330     28
# 2019-02-01           4542       39399     292988        21796   1316     29
# 2019-03-01           4576       41390     295046        22480   1322     29
# 2019-04-01           4747       42140     295844        23455   1320     30
# 2019-05-01           4801       43261     296380        24751   1315     30
#
#               long_term_deposit  mortgage  payroll  payroll_account  \
# pk_partition
# 2018-01-01                 4884        15     8145            13478
# 2018-02-01                 4956        15     8889            14246
# 2018-03-01                 4965        17     9735            14989
# 2018-04-01                 5107        17     9905            15825
# 2018-05-01                 5356        18     9994            16697
# 2018-06-01                 5588        19    10946            15540
# 2018-07-01                 5796        20    11888            16916
# 2018-08-01                 5923        20    11383            18118
# 2018-09-01                 6158        20    11850            18862
# 2018-10-01                 6380        19    12454            19945
# 2018-11-01                 6447        19    13032            21437
# 2018-12-01                 6749        19    14452            21359
# 2019-01-01                 6659        20    12058            22324
# 2019-02-01                 6658        20    14378            23264
# 2019-03-01                 6537        20    15114            24390
# 2019-04-01                 6368        23    15231            25501
# 2019-05-01                 6129        23    16333            26529
#
#               pension_plan  securities  short_term_deposit
# pk_partition
# 2018-01-01            8835         932                 883
# 2018-02-01            9496         965                1343
# 2018-03-01            9882         965                1664
# 2018-04-01           10560         983                1740
# 2018-05-01           10148        1012                1455
# 2018-06-01           11635        1019                1244
# 2018-07-01           12779        1053                1282
# 2018-08-01           12126        1133                1335
# 2018-09-01           12624        1201                1386
# 2018-10-01           13223        1348                1374
# 2018-11-01           13818        1360                1018
# 2018-12-01           15324        1420                 528
# 2019-01-01           12538        1655                 125
# 2019-02-01           15265        1747                  11
# 2019-03-01           15976        1769                   2
# 2019-04-01           16220        1782                   2
# 2019-05-01           17353        1789                   2

# %%
shifted_columns = []
for column in TOTAL_STOCK.columns:
    new_column_name = column + '_shifted'
    shifted_column = TOTAL_STOCK[column].shift(1)
    TOTAL_STOCK[new_column_name] = shifted_column
    shifted_columns.append(new_column_name)

# %%
INVENTARIO = TOTAL_STOCK.merge(TOTAL_VENTAS, on=['pk_partition'], how='left')

# %%
INVENTARIO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17 entries, 2018-01-01 to 2019-05-01
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit_card                 17 non-null     int64
#  1   debit_card                  17 non-null     int64
#  2   em_acount                   17 non-null     int64
#  3   emc_account                 17 non-null     int64
#  4   funds                       17 non-null     int64
#  5   loans                       17 non-null     int8
#  6   long_term_deposit           17 non-null     int64
#  7   mortgage                    17 non-null     int8
#  8   payroll                     17 non-null     int64
#  9   payroll_account             17 non-null     int64
#  10  pension_plan                17 non-null     int64
#  11  securities                  17 non-null     int64
#  12  short_term_deposit          17 non-null     int64
#  13  credit_card_shifted         16 non-null     float64
#  14  debit_card_shifted          16 non-null     float64
#  15  em_acount_shifted           16 non-null     float64
#  16  emc_account_shifted         16 non-null     float64
#  17  funds_shifted               16 non-null     float64
#  18  loans_shifted               16 non-null     float64
#  19  long_term_deposit_shifted   16 non-null     float64
#  20  mortgage_shifted            16 non-null     float64
#  21  payroll_shifted             16 non-null     float64
#  22  payroll_account_shifted     16 non-null     float64
#  23  pension_plan_shifted        16 non-null     float64
#  24  securities_shifted          16 non-null     float64
#  25  short_term_deposit_shifted  16 non-null     float64
#  26  credit_card_venta           16 non-null     float64
#  27  debit_card_venta            16 non-null     float64
#  28  em_acount_venta             16 non-null     float64
#  29  emc_account_venta           16 non-null     float64
#  30  funds_venta                 16 non-null     float64
#  31  loans_venta                 16 non-null     float64
#  32  long_term_deposit_venta     16 non-null     float64
#  33  mortgage_venta              16 non-null     float64
#  34  payroll_venta               16 non-null     float64
#  35  payroll_account_venta       16 non-null     float64
#  36  pension_plan_venta          16 non-null     float64
#  37  securities_venta            16 non-null     float64
#  38  short_term_deposit_venta    16 non-null     float64
# dtypes: float64(26), int64(11), int8(2)
# memory usage: 5.1 KB

# %%
productos = ['short_term_deposit', 'loans', 'mortgage', 'funds', 'securities', 'long_term_deposit', 'credit_card', 'payroll', 'pension_plan', 'payroll_account', 'emc_account', 'debit_card', 'em_acount']

for producto in productos:
    column_shifted = producto + '_shifted'
    column_venta = producto + '_venta'
    column_baja = producto + '_baja'


    def calculate_total(row, column_shifted, producto, column_venta):
      result = row[column_shifted] - row[producto] + row[column_venta]
      if result < 0:
        return 0
      else:
        return result

    INVENTARIO[column_baja] = INVENTARIO.apply(calculate_total, axis=1, args=(column_shifted, producto, column_venta))

# %%
INVENTARIO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17 entries, 2018-01-01 to 2019-05-01
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit_card                 17 non-null     int64
#  1   debit_card                  17 non-null     int64
#  2   em_acount                   17 non-null     int64
#  3   emc_account                 17 non-null     int64
#  4   funds                       17 non-null     int64
#  5   loans                       17 non-null     int8
#  6   long_term_deposit           17 non-null     int64
#  7   mortgage                    17 non-null     int8
#  8   payroll                     17 non-null     int64
#  9   payroll_account             17 non-null     int64
#  10  pension_plan                17 non-null     int64
#  11  securities                  17 non-null     int64
#  12  short_term_deposit          17 non-null     int64
#  13  credit_card_shifted         16 non-null     float64
#  14  debit_card_shifted          16 non-null     float64
#  15  em_acount_shifted           16 non-null     float64
#  16  emc_account_shifted         16 non-null     float64
#  17  funds_shifted               16 non-null     float64
#  18  loans_shifted               16 non-null     float64
#  19  long_term_deposit_shifted   16 non-null     float64
#  20  mortgage_shifted            16 non-null     float64
#  21  payroll_shifted             16 non-null     float64
#  22  payroll_account_shifted     16 non-null     float64
#  23  pension_plan_shifted        16 non-null     float64
#  24  securities_shifted          16 non-null     float64
#  25  short_term_deposit_shifted  16 non-null     float64
#  26  credit_card_venta           16 non-null     float64
#  27  debit_card_venta            16 non-null     float64
#  28  em_acount_venta             16 non-null     float64
#  29  emc_account_venta           16 non-null     float64
#  30  funds_venta                 16 non-null     float64
#  31  loans_venta                 16 non-null     float64
#  32  long_term_deposit_venta     16 non-null     float64
#  33  mortgage_venta              16 non-null     float64
#  34  payroll_venta               16 non-null     float64
#  35  payroll_account_venta       16 non-null     float64
#  36  pension_plan_venta          16 non-null     float64
#  37  securities_venta            16 non-null     float64
#  38  short_term_deposit_venta    16 non-null     float64
#  39  short_term_deposit_baja     16 non-null     float64
#  40  loans_baja                  16 non-null     float64
#  41  mortgage_baja               16 non-null     float64
#  42  funds_baja                  16 non-null     float64
#  43  securities_baja             16 non-null     float64
#  44  long_term_deposit_baja      16 non-null     float64
#  45  credit_card_baja            16 non-null     float64
#  46  payroll_baja                16 non-null     float64
#  47  pension_plan_baja           16 non-null     float64
#  48  payroll_account_baja        16 non-null     float64
#  49  emc_account_baja            16 non-null     float64
#  50  debit_card_baja             16 non-null     float64
#  51  em_acount_baja              16 non-null     float64
# dtypes: float64(39), int64(11), int8(2)
# memory usage: 6.8 KB

# %%
INVENTARIO = INVENTARIO.T

# %%
INVENTARIO
# Out:
# pk_partition                2018-01-01  2018-02-01  2018-03-01  2018-04-01  \
# credit_card                     3325.0      3282.0      3511.0      3725.0
# debit_card                     24696.0     25448.0     27046.0     27764.0
# em_acount                     215293.0    217098.0    218683.0    219816.0
# emc_account                    15320.0     15827.0     16428.0     16947.0
# funds                            786.0       872.0       969.0      1084.0
# loans                             19.0        19.0        23.0        24.0
# long_term_deposit               4884.0      4956.0      4965.0      5107.0
# mortgage                          15.0        15.0        17.0        17.0
# payroll                         8145.0      8889.0      9735.0      9905.0
# payroll_account                13478.0     14246.0     14989.0     15825.0
# pension_plan                    8835.0      9496.0      9882.0     10560.0
# securities                       932.0       965.0       965.0       983.0
# short_term_deposit               883.0      1343.0      1664.0      1740.0
# credit_card_shifted                NaN      3325.0      3282.0      3511.0
# debit_card_shifted                 NaN     24696.0     25448.0     27046.0
# em_acount_shifted                  NaN    215293.0    217098.0    218683.0
# emc_account_shifted                NaN     15320.0     15827.0     16428.0
# funds_shifted                      NaN       786.0       872.0       969.0
# loans_shifted                      NaN        19.0        19.0        23.0
# long_term_deposit_shifted          NaN      4884.0      4956.0      4965.0
# mortgage_shifted                   NaN        15.0        15.0        17.0
# payroll_shifted                    NaN      8145.0      8889.0      9735.0
# payroll_account_shifted            NaN     13478.0     14246.0     14989.0
# pension_plan_shifted               NaN      8835.0      9496.0      9882.0
# securities_shifted                 NaN       932.0       965.0       965.0
# short_term_deposit_shifted         NaN       883.0      1343.0      1664.0
# credit_card_venta                  NaN       510.0       551.0       400.0
# debit_card_venta                   NaN      3708.0      2691.0      2122.0
# em_acount_venta                    NaN      4156.0      3521.0      3004.0
# emc_account_venta                  NaN       807.0       786.0       705.0
# funds_venta                        NaN        97.0       118.0       124.0
# loans_venta                        NaN         0.0         4.0         3.0
# long_term_deposit_venta            NaN       225.0       249.0       230.0
# mortgage_venta                     NaN         0.0         2.0         1.0
# payroll_venta                      NaN      1966.0      1080.0       987.0
# payroll_account_venta              NaN       974.0       888.0       909.0
# pension_plan_venta                 NaN      2006.0      1088.0      1025.0
# securities_venta                   NaN        68.0        39.0        33.0
# short_term_deposit_venta           NaN       665.0       651.0       419.0
# short_term_deposit_baja            NaN       205.0       330.0       343.0
# loans_baja                         NaN         0.0         0.0         2.0
# mortgage_baja                      NaN         0.0         0.0         1.0
# funds_baja                         NaN        11.0        21.0         9.0
# securities_baja                    NaN        35.0        39.0        15.0
# long_term_deposit_baja             NaN       153.0       240.0        88.0
# credit_card_baja                   NaN       553.0       322.0       186.0
# payroll_baja                       NaN      1222.0       234.0       817.0
# pension_plan_baja                  NaN      1345.0       702.0       347.0
# payroll_account_baja               NaN       206.0       145.0        73.0
# emc_account_baja                   NaN       300.0       185.0       186.0
# debit_card_baja                    NaN      2956.0      1093.0      1404.0
# em_acount_baja                     NaN      2351.0      1936.0      1871.0
#
# pk_partition                2018-05-01  2018-06-01  2018-07-01  2018-08-01  \
# credit_card                     3797.0      4002.0      4137.0      4206.0
# debit_card                     27911.0     28828.0     29578.0     29205.0
# em_acount                     221291.0    224328.0    234324.0    245980.0
# emc_account                    17569.0     17950.0     18185.0     18333.0
# funds                           1145.0      1159.0      1172.0      1219.0
# loans                             27.0        27.0        28.0        29.0
# long_term_deposit               5356.0      5588.0      5796.0      5923.0
# mortgage                          18.0        19.0        20.0        20.0
# payroll                         9994.0     10946.0     11888.0     11383.0
# payroll_account                16697.0     15540.0     16916.0     18118.0
# pension_plan                   10148.0     11635.0     12779.0     12126.0
# securities                      1012.0      1019.0      1053.0      1133.0
# short_term_deposit              1455.0      1244.0      1282.0      1335.0
# credit_card_shifted             3725.0      3797.0      4002.0      4137.0
# debit_card_shifted             27764.0     27911.0     28828.0     29578.0
# em_acount_shifted             219816.0    221291.0    224328.0    234324.0
# emc_account_shifted            16947.0     17569.0     17950.0     18185.0
# funds_shifted                   1084.0      1145.0      1159.0      1172.0
# loans_shifted                     24.0        27.0        27.0        28.0
# long_term_deposit_shifted       5107.0      5356.0      5588.0      5796.0
# mortgage_shifted                  17.0        18.0        19.0        20.0
# payroll_shifted                 9905.0      9994.0     10946.0     11888.0
# payroll_account_shifted        15825.0     16697.0     15540.0     16916.0
# pension_plan_shifted           10560.0     10148.0     11635.0     12779.0
# securities_shifted               983.0      1012.0      1019.0      1053.0
# short_term_deposit_shifted      1740.0      1455.0      1244.0      1282.0
# credit_card_venta                373.0       406.0       390.0       331.0
# debit_card_venta                1804.0      1834.0      1942.0      1943.0
# em_acount_venta                 3065.0      4711.0     12439.0     14129.0
# emc_account_venta                712.0       561.0       403.0       339.0
# funds_venta                       81.0        51.0        52.0        58.0
# loans_venta                        3.0         0.0         1.0         2.0
# long_term_deposit_venta          340.0       371.0       417.0       312.0
# mortgage_venta                     1.0         1.0         1.0         0.0
# payroll_venta                    918.0      1091.0      1550.0      1073.0
# payroll_account_venta            916.0       945.0      1295.0      1267.0
# pension_plan_venta               927.0      1113.0      1621.0      1097.0
# securities_venta                  38.0        34.0        41.0        73.0
# short_term_deposit_venta         380.0       440.0       450.0       430.0
# short_term_deposit_baja          665.0       651.0       412.0       377.0
# loans_baja                         0.0         0.0         0.0         1.0
# mortgage_baja                      0.0         0.0         0.0         0.0
# funds_baja                        20.0        37.0        39.0        11.0
# securities_baja                    9.0        27.0         7.0         0.0
# long_term_deposit_baja            91.0       139.0       209.0       185.0
# credit_card_baja                 301.0       201.0       255.0       262.0
# payroll_baja                     829.0       139.0       608.0      1578.0
# pension_plan_baja               1339.0         0.0       477.0      1750.0
# payroll_account_baja              44.0      2102.0         0.0        65.0
# emc_account_baja                  90.0       180.0       168.0       191.0
# debit_card_baja                 1657.0       917.0      1192.0      2316.0
# em_acount_baja                  1590.0      1674.0      2443.0      2473.0
#
# pk_partition                2018-09-01  2018-10-01  2018-11-01  2018-12-01  \
# credit_card                     4289.0      4385.0      4512.0      4536.0
# debit_card                     31684.0     34372.0     35466.0     37430.0
# em_acount                     261210.0    277707.0    284900.0    288928.0
# emc_account                    18618.0     18844.0     19494.0     20043.0
# funds                           1237.0      1249.0      1282.0      1322.0
# loans                             31.0        33.0        32.0        30.0
# long_term_deposit               6158.0      6380.0      6447.0      6749.0
# mortgage                          20.0        19.0        19.0        19.0
# payroll                        11850.0     12454.0     13032.0     14452.0
# payroll_account                18862.0     19945.0     21437.0     21359.0
# pension_plan                   12624.0     13223.0     13818.0     15324.0
# securities                      1201.0      1348.0      1360.0      1420.0
# short_term_deposit              1386.0      1374.0      1018.0       528.0
# credit_card_shifted             4206.0      4289.0      4385.0      4512.0
# debit_card_shifted             29205.0     31684.0     34372.0     35466.0
# em_acount_shifted             245980.0    261210.0    277707.0    284900.0
# emc_account_shifted            18333.0     18618.0     18844.0     19494.0
# funds_shifted                   1219.0      1237.0      1249.0      1282.0
# loans_shifted                     29.0        31.0        33.0        32.0
# long_term_deposit_shifted       5923.0      6158.0      6380.0      6447.0
# mortgage_shifted                  20.0        20.0        19.0        19.0
# payroll_shifted                11383.0     11850.0     12454.0     13032.0
# payroll_account_shifted        18118.0     18862.0     19945.0     21437.0
# pension_plan_shifted           12126.0     12624.0     13223.0     13818.0
# securities_shifted              1133.0      1201.0      1348.0      1360.0
# short_term_deposit_shifted      1335.0      1386.0      1374.0      1018.0
# credit_card_venta                281.0       287.0       259.0       221.0
# debit_card_venta                2514.0      3426.0      2908.0      2483.0
# em_acount_venta                17513.0     18988.0     10517.0      6223.0
# emc_account_venta                474.0       447.0       799.0       767.0
# funds_venta                       34.0        37.0        50.0        56.0
# loans_venta                        2.0         2.0         0.0         1.0
# long_term_deposit_venta          450.0       453.0       338.0       410.0
# mortgage_venta                     0.0         0.0         0.0         0.0
# payroll_venta                    904.0      1184.0      1270.0      1366.0
# payroll_account_venta            815.0      1077.0      1590.0      1955.0
# pension_plan_venta               940.0      1208.0      1296.0      1449.0
# securities_venta                  65.0       173.0        35.0        78.0
# short_term_deposit_venta         496.0       411.0        93.0         6.0
# short_term_deposit_baja          445.0       423.0       449.0       496.0
# loans_baja                         0.0         0.0         1.0         3.0
# mortgage_baja                      0.0         1.0         0.0         0.0
# funds_baja                        16.0        25.0        17.0        16.0
# securities_baja                    0.0        26.0        23.0        18.0
# long_term_deposit_baja           215.0       231.0       271.0       108.0
# credit_card_baja                 198.0       191.0       132.0       197.0
# payroll_baja                     437.0       580.0       692.0         0.0
# pension_plan_baja                442.0       609.0       701.0         0.0
# payroll_account_baja              71.0         0.0        98.0      2033.0
# emc_account_baja                 189.0       221.0       149.0       218.0
# debit_card_baja                   35.0       738.0      1814.0       519.0
# em_acount_baja                  2283.0      2491.0      3324.0      2195.0
#
# pk_partition                2019-01-01  2019-02-01  2019-03-01  2019-04-01  \
# credit_card                     4493.0      4542.0      4576.0      4747.0
# debit_card                     37350.0     39399.0     41390.0     42140.0
# em_acount                     291786.0    292988.0    295046.0    295844.0
# emc_account                    20921.0     21796.0     22480.0     23455.0
# funds                           1330.0      1316.0      1322.0      1320.0
# loans                             28.0        29.0        29.0        30.0
# long_term_deposit               6659.0      6658.0      6537.0      6368.0
# mortgage                          20.0        20.0        20.0        23.0
# payroll                        12058.0     14378.0     15114.0     15231.0
# payroll_account                22324.0     23264.0     24390.0     25501.0
# pension_plan                   12538.0     15265.0     15976.0     16220.0
# securities                      1655.0      1747.0      1769.0      1782.0
# short_term_deposit               125.0        11.0         2.0         2.0
# credit_card_shifted             4536.0      4493.0      4542.0      4576.0
# debit_card_shifted             37430.0     37350.0     39399.0     41390.0
# em_acount_shifted             288928.0    291786.0    292988.0    295046.0
# emc_account_shifted            20043.0     20921.0     21796.0     22480.0
# funds_shifted                   1322.0      1330.0      1316.0      1322.0
# loans_shifted                     30.0        28.0        29.0        29.0
# long_term_deposit_shifted       6749.0      6659.0      6658.0      6537.0
# mortgage_shifted                  19.0        20.0        20.0        20.0
# payroll_shifted                14452.0     12058.0     14378.0     15114.0
# payroll_account_shifted        21359.0     22324.0     23264.0     24390.0
# pension_plan_shifted           15324.0     12538.0     15265.0     15976.0
# securities_shifted              1420.0      1655.0      1747.0      1769.0
# short_term_deposit_shifted       528.0       125.0        11.0         2.0
# credit_card_venta                215.0       248.0       249.0       236.0
# debit_card_venta                2160.0      2537.0      2590.0      2129.0
# em_acount_venta                 5137.0      3952.0      4210.0      3012.0
# emc_account_venta               1017.0      1066.0       878.0      1113.0
# funds_venta                       34.0        25.0        20.0        26.0
# loans_venta                        1.0         1.0         3.0         2.0
# long_term_deposit_venta          178.0       192.0        50.0        10.0
# mortgage_venta                     1.0         0.0         0.0         3.0
# payroll_venta                    880.0      1078.0      1143.0      1092.0
# payroll_account_venta           1055.0      1046.0      1120.0      1086.0
# pension_plan_venta               946.0      1102.0      1186.0      1148.0
# securities_venta                 248.0       113.0        57.0        32.0
# short_term_deposit_venta           0.0         0.0         0.0         0.0
# short_term_deposit_baja          403.0       114.0         9.0         0.0
# loans_baja                         3.0         0.0         3.0         1.0
# mortgage_baja                      0.0         0.0         0.0         0.0
# funds_baja                        26.0        39.0        14.0        28.0
# securities_baja                   13.0        21.0        35.0        19.0
# long_term_deposit_baja           268.0       193.0       171.0       179.0
# credit_card_baja                 258.0       199.0       215.0        65.0
# payroll_baja                    3274.0         0.0       407.0       975.0
# pension_plan_baja               3732.0         0.0       475.0       904.0
# payroll_account_baja              90.0       106.0         0.0         0.0
# emc_account_baja                 139.0       191.0       194.0       138.0
# debit_card_baja                 2240.0       488.0       599.0      1379.0
# em_acount_baja                  2279.0      2750.0      2152.0      2214.0
#
# pk_partition                2019-05-01
# credit_card                     4801.0
# debit_card                     43261.0
# em_acount                     296380.0
# emc_account                    24751.0
# funds                           1315.0
# loans                             30.0
# long_term_deposit               6129.0
# mortgage                          23.0
# payroll                        16333.0
# payroll_account                26529.0
# pension_plan                   17353.0
# securities                      1789.0
# short_term_deposit                 2.0
# credit_card_shifted             4747.0
# debit_card_shifted             42140.0
# em_acount_shifted             295844.0
# emc_account_shifted            23455.0
# funds_shifted                   1320.0
# loans_shifted                     30.0
# long_term_deposit_shifted       6368.0
# mortgage_shifted                  23.0
# payroll_shifted                15231.0
# payroll_account_shifted        25501.0
# pension_plan_shifted           16220.0
# securities_shifted              1782.0
# short_term_deposit_shifted         2.0
# credit_card_venta                249.0
# debit_card_venta                2049.0
# em_acount_venta                 2858.0
# emc_account_venta               1449.0
# funds_venta                       17.0
# loans_venta                        0.0
# long_term_deposit_venta            2.0
# mortgage_venta                     0.0
# payroll_venta                   1168.0
# payroll_account_venta           1172.0
# pension_plan_venta              1217.0
# securities_venta                  30.0
# short_term_deposit_venta           0.0
# short_term_deposit_baja            0.0
# loans_baja                         0.0
# mortgage_baja                      0.0
# funds_baja                        22.0
# securities_baja                   23.0
# long_term_deposit_baja           241.0
# credit_card_baja                 195.0
# payroll_baja                      66.0
# pension_plan_baja                 84.0
# payroll_account_baja             144.0
# emc_account_baja                 153.0
# debit_card_baja                  928.0
# em_acount_baja                  2322.0

# %%
INVENTARIO.columns.tolist()
# Out:
# [Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-03-01 00:00:00'),
#  Timestamp('2018-04-01 00:00:00'),
#  Timestamp('2018-05-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-09-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-12-01 00:00:00'),
#  Timestamp('2019-01-01 00:00:00'),
#  Timestamp('2019-02-01 00:00:00'),
#  Timestamp('2019-03-01 00:00:00'),
#  Timestamp('2019-04-01 00:00:00'),
#  Timestamp('2019-05-01 00:00:00')]

# %% [markdown]
# # **5. Exportamos los dataset**

# %%
# Exportar datos procesados en formato .csv para su uso en Power BI
merged_data.to_csv("informacion_clientes.csv", index=False)
INVENTARIO.to_csv("informacion_productos.csv", index=True)
merged_data_2.to_csv("informacion_ventas.csv", index=False)

# %%
# Lo descargamos
files.download("informacion_clientes.csv")
files.download("informacion_productos.csv")
files.download("informacion_ventas.csv")
